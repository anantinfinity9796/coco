# %% [markdown]
# #### Image captioning Model
# In this we would train an image captioning model on top of our multilabel resenet. An try to train to predict the captions of the image.

# %% [markdown]
# #### Changes that need to be made to implement the model
# 1. We would need to change the dataloader to output the caption vector along with the images.
# 2. We would also need to train a maybe a recurrent neural network to output the captions.

# %% [markdown]
# 1. First we will take the resnet output feature vector and we will pass it  as the starting hidden state of the RNN.
# 2. we will use word level embeddings for the inputs.
# 3. We will also use start and end tokens.
# 4. Then we will output the probabilities of the next word.
# 5. Then we will jointly train the full network to generate the captions for the images.
# 6. For training the RNN we can keep a block size length of 5 words.

# %% [markdown]
# ##### So lets start by modiying the dataloder to output the captions.

# %%
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision
import torch.optim as optim
import torch.nn as nn
from torchinfo import summary
from tqdm import tqdm, trange
torch.random.manual_seed(42)
torch.cuda.manual_seed(42)
from torchvision.transforms import Compose, Resize, Normalize, CenterCrop
from torchvision.models import resnet50, ResNet50_Weights
from torch.utils.tensorboard import SummaryWriter
import datetime as dt
import json
import torchtext
from collections import OrderedDict
import nltk

# %%
image_captions_df = pd.read_parquet('F://coco/captions/image_captions_df_new.parquet')
image_captions_df
# Out:
#        image_id                        file_name  \
# 0         57870  COCO_train2014_000000057870.jpg
# 1        384029  COCO_train2014_000000384029.jpg
# 2        222016  COCO_train2014_000000222016.jpg
# 3        520950  COCO_train2014_000000520950.jpg
# 4         69675  COCO_train2014_000000069675.jpg
# ...         ...                              ...
# 66658    360271  COCO_train2014_000000360271.jpg
# 66659    471345  COCO_train2014_000000471345.jpg
# 66660    444010  COCO_train2014_000000444010.jpg
# 66661    565004  COCO_train2014_000000565004.jpg
# 66662    516168  COCO_train2014_000000516168.jpg
#
#                                                 captions  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66659  [[a, table, topped, with, two, white, plates, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                        caption_token_set  \
# 0      [arrangement, is, flower, on, table, blue, top...
# 1      [types, desserts, person, is, kitchen, many, u...
# 2      [inside, person, image, standing, is, an, that...
# 3      [is, on, that, kitchen, all, utilizes, with, i...
# 4      [child, woman, person, on, women, an, together...
# ...                                                  ...
# 66658  [woman, another, dinner., sitting, is, watchin...
# 66659  [lobster,, rice., sitting, is, on, table, sit,...
# 66660  [woman, jovial, sitting, table, group, togethe...
# 66661  [another, is, on, table, wine, with, red, glas...
# 66662  [paper, glases, standing, is, sitting, on, tab...
#
#                                             idx_captions  \
# 0      [[27, 13, 25, 23, 9, 30, 12, 19], [27, 22, 13,...
# 1      [[27, 53, 56, 33, 29, 27, 35, 42, 29, 50], [27...
# 2      [[27, 66, 62, 67, 65, 61, 27, 53, 1, 59, 29], ...
# 3      [[20, 35, 1, 73, 28, 80, 3, 20, 75], [27, 35, ...
# 4      [[27, 88, 12, 89, 94, 98, 29, 20, 99], [27, 89...
# ...                                                  ...
# 66658  [[90, 215, 102, 27, 311, 4, 7, 140, 145, 102, ...
# 66659  [[27, 4, 283, 7, 103, 118, 427, 28, 97, 163, 1...
# 66660  [[27, 362, 28, 2829, 215, 144, 102, 27, 4, 330...
# 66661  [[418, 319, 6776, 161, 27, 686, 139, 27, 4], [...
# 66662  [[27, 53, 1, 59, 135, 27, 3694, 7, 15795], [27...
#
#                                                   tokens
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66659  [[a, table, topped, with, two, white, plates, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
# [66663 rows x 6 columns]

# %%
vocab_dict = {}
def make_vocab(token_list):
    for tokens in  token_list:
        for token in tokens:
            if token in vocab_dict:
                vocab_dict[token] +=1
            else:
                vocab_dict[token] = 1

image_captions_df['tokens'].apply(lambda x : make_vocab(x))
vocab_dict
# Out:
# {'a': 551261,
#  'restaurant': 1446,
#  'has': 8483,
#  'modern': 610,
#  'wooden': 5196,
#  'tables': 746,
#  'and': 79581,
#  'chairs': 1711,
#  '.': 250427,
#  'long': 1976,
#  'table': 17829,
#  'with': 86972,
#  'rattan': 3,
#  'rounded': 20,
#  'back': 3201,
#  'plant': 607,
#  'on': 121090,
#  'top': 12320,
#  'of': 113888,
#  'it': 14840,
#  'surrounded': 1058,
#  'flower': 729,
#  'arrangement': 162,
#  'in': 103832,
#  'the': 110813,
#  'middle': 2291,
#  'for': 6175,
#  'meetings': 1,
#  'is': 55372,
#  'adorned': 73,
#  'blue': 7708,
#  'accents': 45,
#  'man': 41987,
#  'preparing': 1260,
#  'desserts': 165,
#  'kitchen': 7968,
#  'covered': 4000,
#  'frosting': 242,
#  'chef': 225,
#  'decorating': 39,
#  'many': 3804,
#  'small': 11447,
#  'pastries': 328,
#  'baker': 20,
#  'prepares': 434,
#  'various': 1516,
#  'types': 589,
#  'baked': 290,
#  'goods': 97,
#  'close': 3863,
#  'up': 11683,
#  'person': 13988,
#  'grabbing': 95,
#  'pastry': 288,
#  'container': 462,
#  'hand': 2687,
#  'touching': 228,
#  'big': 3151,
#  'red': 9863,
#  'telephone': 180,
#  'booth': 135,
#  'that': 15727,
#  'standing': 24643,
#  'inside': 3143,
#  'phone': 4302,
#  'this': 3764,
#  'an': 28524,
#  'image': 2203,
#  'using': 1509,
#  'full': 2308,
#  'spices': 43,
#  'rack': 472,
#  'counter': 2923,
#  ',': 25313,
#  'oven': 1690,
#  'other': 6927,
#  'accessories': 136,
#  'utilizes': 4,
#  'all': 1486,
#  'its': 3335,
#  'space': 451,
#  'pots': 324,
#  'pans': 244,
#  'display': 1873,
#  'very': 3770,
#  'stove': 1700,
#  'shelf': 787,
#  'child': 3577,
#  'woman': 20114,
#  'are': 23146,
#  'cooking': 648,
#  'glances': 2,
#  'at': 24295,
#  'young': 9829,
#  'girl': 5522,
#  "'s": 4051,
#  'stovetop': 18,
#  'food': 7947,
#  'older': 970,
#  'two': 27564,
#  'women': 2895,
#  'together': 3460,
#  'huge': 486,
#  'clock': 6072,
#  'wall': 3710,
#  'near': 11100,
#  'large': 14112,
#  'face': 1262,
#  'numbers': 74,
#  'end': 553,
#  'above': 2019,
#  'radiator': 29,
#  'bicycle': 1308,
#  'parked': 7316,
#  'cabinets': 1036,
#  'black': 10686,
#  'leaning': 850,
#  'against': 1462,
#  'white': 20250,
#  'bike': 2244,
#  'backpack': 404,
#  'located': 131,
#  'by': 9679,
#  'people': 24049,
#  'truck': 4545,
#  'one': 4867,
#  'looking': 6729,
#  'order': 85,
#  'beanie': 27,
#  'glasses': 1935,
#  'leans': 215,
#  'over': 5356,
#  'cart': 633,
#  'down': 13430,
#  'piece': 2158,
#  'paper': 1443,
#  'beard': 159,
#  'shirt': 2834,
#  'making': 870,
#  'some': 13771,
#  'working': 758,
#  'behind': 3776,
#  'slides': 49,
#  'pizza': 7684,
#  'into': 3561,
#  'brick': 1320,
#  'wearing': 5672,
#  'apron': 123,
#  'next': 20914,
#  'to': 38478,
#  'ball': 6532,
#  'cap': 259,
#  'getting': 1631,
#  'ready': 2385,
#  'his': 11011,
#  'bread': 936,
#  'be': 1410,
#  'cutting': 1899,
#  'roast': 60,
#  'fork': 907,
#  'knife': 1064,
#  'there': 7150,
#  'meat': 1391,
#  'board': 4727,
#  'slicing': 108,
#  'hot': 1770,
#  'dark': 1043,
#  'several': 5224,
#  'room': 10343,
#  'counters': 168,
#  'shelves': 343,
#  'filled': 3587,
#  'wood': 1531,
#  'dishwasher': 118,
#  'sink': 4701,
#  'refrigerator': 1811,
#  'window': 4062,
#  'opened': 242,
#  'appliances': 594,
#  'icebox': 18,
#  'fridge': 446,
#  'microwave': 985,
#  'cook': 119,
#  'under': 3648,
#  'lamp': 564,
#  'chief': 2,
#  'plating': 7,
#  'out': 5617,
#  'pan': 821,
#  'sous': 1,
#  'adding': 16,
#  'sauce': 694,
#  'plate': 10936,
#  'pass': 186,
#  'adults': 375,
#  'laptop': 4626,
#  'computers': 572,
#  'while': 8429,
#  'sitting': 29410,
#  'outdoor': 924,
#  'venue': 12,
#  'row': 990,
#  'men': 6142,
#  'laptops': 555,
#  'side': 6771,
#  'building': 6665,
#  'number': 1038,
#  'siting': 199,
#  'bench': 5005,
#  'sit': 2204,
#  'each': 3927,
#  'vegetables': 2525,
#  'scallions': 6,
#  'chopping': 64,
#  'stands': 3183,
#  'as': 4312,
#  'he': 1160,
#  'cuts': 138,
#  'onions': 365,
#  'front': 10803,
#  'garage': 244,
#  'chefs': 139,
#  'patrons': 40,
#  'exit': 43,
#  'view': 2969,
#  'shows': 592,
#  'leaving': 143,
#  'elaborate': 55,
#  'entry': 26,
#  'way': 965,
#  'includes': 250,
#  'curved': 62,
#  'revealing': 20,
#  'work': 432,
#  'features': 272,
#  'see': 324,
#  'walking': 8582,
#  'outside': 4406,
#  'asian': 410,
#  'dining': 855,
#  'set': 1470,
#  'casual': 26,
#  'meal': 1056,
#  'flowers': 2597,
#  'topped': 1652,
#  'four': 2112,
#  'place': 535,
#  'mats': 19,
#  'cloth': 301,
#  'vase': 2491,
#  'roses': 206,
#  'tablecloth': 85,
#  'placemats': 4,
#  'dinning': 53,
#  'napkins': 46,
#  'cluttered': 364,
#  'but': 232,
#  'clean': 756,
#  'kept': 69,
#  'cramped': 27,
#  'empty': 1715,
#  'overhead': 310,
#  'lighting': 146,
#  'home': 1325,
#  'bar': 510,
#  'microwaves': 42,
#  'accented': 10,
#  'color': 228,
#  'prepared': 269,
#  'area': 4930,
#  'meals': 50,
#  'plated': 47,
#  'dishes': 438,
#  'workers': 191,
#  'commercial': 465,
#  'couple': 6321,
#  'bunch': 3038,
#  'upcoming': 8,
#  'dinner': 666,
#  'service': 98,
#  'team': 409,
#  'grill': 285,
#  'burgers': 12,
#  'sandwiches': 505,
#  'meats': 70,
#  'being': 2485,
#  'made': 1107,
#  'laying': 5113,
#  'stomach': 73,
#  'towel': 459,
#  'head': 2042,
#  'someone': 1428,
#  'bed': 6521,
#  'photo': 2982,
#  'someones': 135,
#  'bare': 154,
#  'lying': 1146,
#  'dish': 791,
#  'utensils': 238,
#  'hanging': 1791,
#  'from': 5253,
#  'strange': 110,
#  'interesting': 88,
#  'curtain': 328,
#  'crowded': 500,
#  'walls': 795,
#  'eating': 5075,
#  'noodles': 239,
#  'bowl': 3316,
#  'baby': 2650,
#  'feeding': 551,
#  'himself': 287,
#  'kid': 913,
#  'spoon': 439,
#  'little': 3760,
#  'boy': 6420,
#  'help': 74,
#  'own': 89,
#  'hands': 1247,
#  'skateboard': 5595,
#  'ramp': 1253,
#  'doing': 1895,
#  'trick': 1711,
#  'boys': 939,
#  'skate': 2016,
#  'park': 3908,
#  'group': 12288,
#  'children': 1862,
#  'entertaining': 9,
#  'selves': 2,
#  'skatepark': 43,
#  'performs': 191,
#  'tricks': 548,
#  'onlookers': 117,
#  'watch': 819,
#  'steel': 484,
#  'countertops': 38,
#  'stainless': 359,
#  'wit': 95,
#  'ha': 66,
#  'coffee': 1539,
#  'make': 271,
#  'corner': 1649,
#  'countertop': 94,
#  'field': 11940,
#  'talking': 1695,
#  'grass': 7599,
#  'talks': 181,
#  'cell': 2757,
#  'far': 128,
#  'three': 6248,
#  'others': 595,
#  'blanket': 737,
#  'light': 2887,
#  'colored': 989,
#  'clothing': 288,
#  'tents': 85,
#  'blankent': 1,
#  'cellphone': 623,
#  'lawn': 372,
#  'pair': 1666,
#  'tablet': 145,
#  'perched': 621,
#  'laugh': 31,
#  'they': 624,
#  'look': 1029,
#  'computer': 4108,
#  'smiling': 1679,
#  'happily': 48,
#  'plastic': 741,
#  'bottle': 1052,
#  'wine': 2124,
#  'closeup': 338,
#  'soup': 398,
#  'bowls': 588,
#  'fourths': 2,
#  'corked': 2,
#  'stacks': 60,
#  'pot': 498,
#  'skillet': 61,
#  'dirty': 509,
#  'plates': 1654,
#  'bearded': 115,
#  'colorized': 2,
#  'looks': 1674,
#  'off': 2418,
#  'turned': 215,
#  'observing': 106,
#  'something': 1411,
#  'away': 441,
#  'him': 1129,
#  'tv': 1484,
#  'offering': 18,
#  'taste': 20,
#  'feeds': 75,
#  'bite': 297,
#  'old': 3630,
#  'giving': 259,
#  'test': 5,
#  'sample': 14,
#  'her': 5656,
#  'fed': 65,
#  'spoonful': 10,
#  'leaves': 795,
#  'training': 54,
#  'wheels': 203,
#  'jumpsuit': 5,
#  'sweater': 206,
#  'picnic': 304,
#  'tricycle': 21,
#  'bath': 706,
#  'ornate': 216,
#  'bathroom': 8167,
#  'yellow': 4677,
#  'multicolor': 5,
#  'tiles': 169,
#  'decorated': 1020,
#  'style': 433,
#  'mediterranean': 3,
#  'mosaic': 27,
#  'tiled': 573,
#  'lot': 2662,
#  'fancy': 281,
#  'tile': 472,
#  'tub': 1002,
#  'double': 1957,
#  'vanity': 275,
#  'chandelier': 46,
#  'intricate': 24,
#  'golden': 157,
#  'bathtub': 550,
#  'ceiling': 344,
#  'green': 7032,
#  'mint': 6,
#  'car': 3884,
#  'pictures': 662,
#  'washing': 117,
#  'mirror': 2830,
#  'crying': 23,
#  'photograph': 873,
#  'toddler': 354,
#  'cries': 3,
#  'dress': 712,
#  'riding': 10496,
#  'stand': 2693,
#  'everyone': 34,
#  'bikes': 679,
#  'sunglasses': 408,
#  'dog': 9701,
#  'street': 15606,
#  'solid': 9,
#  'statues': 133,
#  'sidewalk': 2674,
#  'post': 455,
#  'monument': 99,
#  'city': 5777,
#  'atmosphere': 9,
#  'relaxing': 206,
#  'nearby': 493,
#  'anchored': 49,
#  'between': 978,
#  'parking': 2510,
#  'posts': 72,
#  'new': 322,
#  'nothing': 40,
#  'displays': 152,
#  'toilet': 5722,
#  'another': 2803,
#  'beneath': 277,
#  'reflecting': 79,
#  'roll': 212,
#  'scene': 807,
#  'door': 1554,
#  'featuring': 165,
#  'antique': 288,
#  'picture': 4781,
#  'brass': 27,
#  'fixtures': 78,
#  'sinks': 480,
#  'mounted': 527,
#  'soap': 87,
#  'pedestal': 88,
#  'public': 748,
#  'restroom': 353,
#  'bottles': 515,
#  'kneeling': 322,
#  'bicycles': 395,
#  'squatting': 79,
#  'taking': 2123,
#  'crouching': 77,
#  'ground': 2485,
#  'hunkered': 2,
#  'camera': 1778,
#  'bright': 760,
#  'loft': 22,
#  'rustic': 96,
#  'windows': 720,
#  '2': 193,
#  'shower': 1375,
#  'jacuzzi': 16,
#  'furry': 113,
#  'cat': 8582,
#  'pulling': 1190,
#  'carpet': 232,
#  'playful': 22,
#  'pulls': 219,
#  'rug': 354,
#  'playing': 8038,
#  'around': 5007,
#  'upraised': 4,
#  'lid': 219,
#  'bookshelves': 37,
#  'books': 698,
#  'adjacent': 51,
#  'bookshelf': 141,
#  'guy': 1428,
#  'hoodie': 56,
#  'peeing': 5,
#  'note': 75,
#  'written': 170,
#  'purple': 969,
#  'urinating': 9,
#  'unfinished': 48,
#  'lined': 940,
#  'crosswalk': 187,
#  'focusing': 9,
#  'bicyclists': 60,
#  'going': 1795,
#  'road': 5599,
#  'complete': 102,
#  'tab': 7,
#  'plain': 270,
#  'beige': 216,
#  'both': 462,
#  'tub/shower': 6,
#  'destroyed': 25,
#  'mirrored': 36,
#  'cabinet': 430,
#  'run': 424,
#  'paint': 175,
#  'peeling': 53,
#  'need': 36,
#  'remodeling': 18,
#  'repair': 60,
#  'crumbling': 10,
#  'medicine': 31,
#  'abandoned': 117,
#  'peels': 23,
#  'filthy': 27,
#  'floor': 2574,
#  'focus': 107,
#  'bow': 277,
#  'toliet': 14,
#  'wrapped': 278,
#  'ribbon': 91,
#  'carefully': 26,
#  'gift-wrapped': 1,
#  'brand': 39,
#  'across': 2007,
#  'seat': 879,
#  'groups': 87,
#  'tower': 2609,
#  'town': 619,
#  'plaza': 88,
#  'gathered': 568,
#  'square': 416,
#  'strolling': 13,
#  'through': 5059,
#  'open': 3865,
#  'tools': 160,
#  'demolished': 19,
#  'construction': 326,
#  'torn': 24,
#  'remodeled': 57,
#  'glass': 2967,
#  'doors': 320,
#  'clear': 719,
#  'see-through': 4,
#  'grey': 886,
#  'motif': 9,
#  'mirrors': 194,
#  'freshly': 141,
#  'cleaned': 82,
#  'hotel': 647,
#  'closed': 303,
#  'heated': 13,
#  'racks': 61,
#  'built': 193,
#  'hairdryer': 15,
#  'chrome': 81,
#  'sticking': 421,
#  'decently': 1,
#  'sized': 233,
#  'nice': 668,
#  'lights': 1360,
#  'decorative': 256,
#  'commode': 64,
#  'marble': 161,
#  'monogrammed': 4,
#  'symbol': 25,
#  'sculpture': 170,
#  'faucet': 81,
#  'porcelain': 56,
#  'reflected': 112,
#  'rectangular': 63,
#  'single': 583,
#  'right': 495,
#  'lady': 1593,
#  'van': 381,
#  'seagulls': 106,
#  'landing': 342,
#  'watching': 1669,
#  'birds': 1516,
#  'automobile': 43,
#  'where': 412,
#  'seagull': 115,
#  'attacking': 14,
#  'roof': 304,
#  'peoples': 17,
#  'sticks': 203,
#  'brown': 4731,
#  'puts': 96,
#  'moving': 726,
#  'fluffy': 170,
#  'cute': 538,
#  'school': 496,
#  'bus': 7617,
#  'stop': 3605,
#  'sign': 6181,
#  'sits': 5216,
#  'stopped': 720,
#  'showing': 924,
#  'few': 961,
#  'vehicles': 434,
#  'appear': 70,
#  'traveling': 1590,
#  'advertisement': 125,
#  'hummer': 2,
#  'ice': 355,
#  'cubes': 6,
#  'bottom': 308,
#  'boat': 3051,
#  'lots': 1445,
#  'seats': 140,
#  'gate': 364,
#  'bridge': 1031,
#  'train': 10676,
#  'booths': 18,
#  'phillips': 2,
#  '66': 7,
#  'clocks': 401,
#  'posters': 38,
#  'vintage': 488,
#  'photos': 248,
#  'motorcycle': 4269,
#  'displayed': 853,
#  'gas': 209,
#  'station': 2320,
#  'logo': 53,
#  'hangs': 193,
#  'underneath': 679,
#  'resembling': 8,
#  'intersection': 1082,
#  'roadway': 189,
#  'driving': 2238,
#  'cars': 2477,
#  'main': 58,
#  'tall': 2641,
#  'classic': 95,
#  'chevy': 8,
#  'nomad': 1,
#  'busy': 1222,
#  'trash': 346,
#  'can': 850,
#  'simple': 91,
#  'yet': 39,
#  'messy': 288,
#  'garbage': 188,
#  'stall': 353,
#  'pantyhose': 1,
#  'trashcan': 28,
#  'duel': 5,
#  'silver': 994,
#  'faucets': 14,
#  'gray': 1097,
#  'lit': 804,
#  'show': 399,
#  'reflection': 388,
#  'urinals': 177,
#  'shaped': 424,
#  'along': 2344,
#  'short': 288,
#  'pee': 3,
#  'toilets': 314,
#  'attached': 831,
#  'waterless': 1,
#  'more': 131,
#  'disgusting': 17,
#  'than': 91,
#  'line': 1163,
#  'wire': 421,
#  'basket': 630,
#  'transported': 20,
#  'motor': 654,
#  'scooter': 276,
#  'cage': 300,
#  'motocycle': 2,
#  'painted': 763,
#  'rolls': 175,
#  'seen': 800,
#  'slanted': 24,
#  'angle': 59,
#  'napkin': 138,
#  'cup': 1388,
#  'arranged': 320,
#  'crossed': 91,
#  'connected': 116,
#  'speaker': 41,
#  'object': 261,
#  'running': 1208,
#  'held': 274,
#  'eaten': 651,
#  'mixed': 159,
#  'spoons': 96,
#  'resting': 791,
#  'like': 1118,
#  'vases': 608,
#  'ceramic': 133,
#  'fashion': 81,
#  'shown': 1108,
#  'floral': 192,
#  'checkered': 159,
#  'done': 67,
#  'flooring': 151,
#  'checker': 9,
#  'pattern': 90,
#  'checked': 23,
#  'overhang': 12,
#  'outdoors': 420,
#  'awning': 24,
#  'stuff': 217,
#  'stored': 26,
#  'structure': 281,
#  'items': 1260,
#  'fenced': 560,
#  'yard': 696,
#  'brush': 523,
#  'not': 417,
#  'been': 738,
#  'months': 2,
#  'water': 9303,
#  'cleaning': 143,
#  'equipped': 45,
#  'fashionable': 10,
#  'architectural': 24,
#  'subway': 436,
#  'dispensers': 15,
#  'unconventional': 1,
#  'placement': 2,
#  'directly': 59,
#  'below': 493,
#  'horse-drawn': 26,
#  'carriage': 537,
#  'moves': 169,
#  'carrying': 1494,
#  'passengers': 590,
#  'horse': 4830,
#  'drawn': 354,
#  'ride': 694,
#  'rides': 1168,
#  'rails': 120,
#  'handicap': 26,
#  'walk-in': 13,
#  'bathtab': 1,
#  'which': 413,
#  'supplies': 169,
#  'installed': 38,
#  'during': 1952,
#  'hole': 259,
#  'd': 10,
#  'pipe': 198,
#  'installations': 3,
#  'motorcycles': 1501,
#  'alley': 116,
#  'day': 2381,
#  'suzuki': 4,
#  'motorcyles': 5,
#  'behing': 2,
#  'sister': 13,
#  'pants': 301,
#  'kids': 1039,
#  'their': 4877,
#  'metal': 1259,
#  'rail': 703,
#  'airplane': 3272,
#  'writing': 215,
#  'demonstration': 26,
#  'needs': 64,
#  'including': 471,
#  'storage': 114,
#  'blown': 16,
#  'broken': 326,
#  'bikers': 110,
#  'trees': 3980,
#  'highway': 388,
#  'race': 332,
#  'motorcyclists': 92,
#  'freight': 97,
#  'warehouse': 60,
#  'loading/unloading': 1,
#  'frame': 169,
#  'lift': 235,
#  'maroon': 65,
#  'cruising': 16,
#  'sunny': 775,
#  'alongside': 228,
#  'sun': 735,
#  'churros': 3,
#  'chocolate': 978,
#  'deep': 214,
#  'fried': 225,
#  'melted': 51,
#  'entree': 68,
#  'delicious': 161,
#  'churro': 2,
#  'oval': 40,
#  'platter': 235,
#  'cakes': 357,
#  'donuts': 1023,
#  'cake': 5226,
#  'brownies': 23,
#  'doughnuts': 587,
#  'trays': 232,
#  'displaying': 219,
#  'multitude': 12,
#  'assorted': 337,
#  'sweet': 64,
#  'treats': 59,
#  'served': 490,
#  'these': 223,
#  'kinds': 281,
#  'helmet': 746,
#  'motorcyclist': 112,
#  'drives': 404,
#  'high': 1263,
#  'speeds': 37,
#  'cyclist': 53,
#  'sports': 199,
#  'stuffed': 2031,
#  'animal': 1177,
#  'platform': 760,
#  'desk': 3707,
#  'rock': 713,
#  'dead': 170,
#  'video': 1471,
#  'films': 9,
#  'procession': 13,
#  'filming': 19,
#  'scooters': 78,
#  'coming': 875,
#  'passing': 635,
#  'evening': 119,
#  'purpose': 5,
#  'recording': 25,
#  'policeman': 78,
#  'police': 747,
#  'posing': 1679,
#  'cop': 110,
#  'or': 658,
#  'officer': 278,
#  'vehicle': 637,
#  'officers': 193,
#  'cops': 50,
#  'uniforms': 246,
#  'strait': 2,
#  'bmw': 15,
#  'leather': 272,
#  'satchel': 6,
#  'event': 357,
#  'function': 23,
#  'formal': 126,
#  'gathering': 163,
#  'takes': 468,
#  'turn': 316,
#  'crowd': 1600,
#  'spectators': 202,
#  'curve': 73,
#  'turning': 152,
#  '#': 11,
#  '20': 10,
#  'handle': 159,
#  'bars': 102,
#  'rounding': 36,
#  'employee': 20,
#  'doorway': 288,
#  'passenger': 1303,
#  'entrance': 158,
#  'commuter': 283,
#  'cycle': 124,
#  'house': 1334,
#  'cans': 82,
#  'umbrella': 4273,
#  'shiny': 154,
#  'railing': 248,
#  'porch': 105,
#  'japanese': 55,
#  '``': 748,
#  "''": 694,
#  'lan': 3,
#  'airport': 1751,
#  'sea': 288,
#  'jetliner': 197,
#  'runway': 1469,
#  'plane': 2981,
#  'taxiing': 39,
#  'ruwnay': 1,
#  'jet': 1394,
#  'coast': 46,
#  'flying': 5778,
#  'air': 4342,
#  'flies': 543,
#  'sky': 3485,
#  'camouflage': 34,
#  'military': 421,
#  'fighter': 293,
#  'hovering': 37,
#  'clouds': 356,
#  'airplanes': 445,
#  'buildings': 1733,
#  'idle': 34,
#  'about': 1286,
#  'land': 343,
#  'jumbo': 129,
#  'tarmac': 650,
#  'adorable': 97,
#  'gir': 2,
#  'stone': 815,
#  'plants': 538,
#  'sideways': 92,
#  'shorts': 433,
#  'slippers': 26,
#  'shaded': 58,
#  'layer': 98,
#  'snow': 6696,
#  'pole': 1365,
#  'traffic': 2851,
#  'signal': 277,
#  'thin': 136,
#  'sheep': 3283,
#  'roaming': 83,
#  'animals': 1572,
#  'grazing': 2056,
#  'hillside': 382,
#  'hill': 2257,
#  'flock': 337,
#  'graze': 312,
#  'rocky': 344,
#  'kicking': 238,
#  'feet': 465,
#  'holding': 15647,
#  'seated': 385,
#  'fence': 2911,
#  'covering': 165,
#  'eyes': 338,
#  'giraffe': 4552,
#  'nose': 244,
#  'pool': 388,
#  'bending': 195,
#  'drinking': 855,
#  'watering': 125,
#  'drink': 885,
#  'airliner': 234,
#  'cliff': 116,
#  'beside': 2036,
#  'plan': 54,
#  'rests': 233,
#  'situated': 46,
#  'mountain': 1792,
#  'rolling': 206,
#  'horned': 63,
#  'type': 297,
#  'coat': 324,
#  'bird': 2985,
#  'neck': 486,
#  'walk': 1360,
#  'background': 3166,
#  'propeller': 235,
#  'airshow': 12,
#  'concrete': 513,
#  'feed': 102,
#  'grassy': 2486,
#  'struggling': 5,
#  'eat': 717,
#  'low': 361,
#  'pasture': 575,
#  'mountains': 687,
#  'fields': 37,
#  'sheared': 17,
#  'herd': 1761,
#  'store': 1062,
#  ...}

# %%
chartoidx = {}
idxtochar = []
for i,word in enumerate(vocab_dict.keys()):
    chartoidx[word] = i
    idxtochar.append(word)

# %%
chartoidx
# Out:
# {'a': 0,
#  'restaurant': 1,
#  'has': 2,
#  'modern': 3,
#  'wooden': 4,
#  'tables': 5,
#  'and': 6,
#  'chairs': 7,
#  '.': 8,
#  'long': 9,
#  'table': 10,
#  'with': 11,
#  'rattan': 12,
#  'rounded': 13,
#  'back': 14,
#  'plant': 15,
#  'on': 16,
#  'top': 17,
#  'of': 18,
#  'it': 19,
#  'surrounded': 20,
#  'flower': 21,
#  'arrangement': 22,
#  'in': 23,
#  'the': 24,
#  'middle': 25,
#  'for': 26,
#  'meetings': 27,
#  'is': 28,
#  'adorned': 29,
#  'blue': 30,
#  'accents': 31,
#  'man': 32,
#  'preparing': 33,
#  'desserts': 34,
#  'kitchen': 35,
#  'covered': 36,
#  'frosting': 37,
#  'chef': 38,
#  'decorating': 39,
#  'many': 40,
#  'small': 41,
#  'pastries': 42,
#  'baker': 43,
#  'prepares': 44,
#  'various': 45,
#  'types': 46,
#  'baked': 47,
#  'goods': 48,
#  'close': 49,
#  'up': 50,
#  'person': 51,
#  'grabbing': 52,
#  'pastry': 53,
#  'container': 54,
#  'hand': 55,
#  'touching': 56,
#  'big': 57,
#  'red': 58,
#  'telephone': 59,
#  'booth': 60,
#  'that': 61,
#  'standing': 62,
#  'inside': 63,
#  'phone': 64,
#  'this': 65,
#  'an': 66,
#  'image': 67,
#  'using': 68,
#  'full': 69,
#  'spices': 70,
#  'rack': 71,
#  'counter': 72,
#  ',': 73,
#  'oven': 74,
#  'other': 75,
#  'accessories': 76,
#  'utilizes': 77,
#  'all': 78,
#  'its': 79,
#  'space': 80,
#  'pots': 81,
#  'pans': 82,
#  'display': 83,
#  'very': 84,
#  'stove': 85,
#  'shelf': 86,
#  'child': 87,
#  'woman': 88,
#  'are': 89,
#  'cooking': 90,
#  'glances': 91,
#  'at': 92,
#  'young': 93,
#  'girl': 94,
#  "'s": 95,
#  'stovetop': 96,
#  'food': 97,
#  'older': 98,
#  'two': 99,
#  'women': 100,
#  'together': 101,
#  'huge': 102,
#  'clock': 103,
#  'wall': 104,
#  'near': 105,
#  'large': 106,
#  'face': 107,
#  'numbers': 108,
#  'end': 109,
#  'above': 110,
#  'radiator': 111,
#  'bicycle': 112,
#  'parked': 113,
#  'cabinets': 114,
#  'black': 115,
#  'leaning': 116,
#  'against': 117,
#  'white': 118,
#  'bike': 119,
#  'backpack': 120,
#  'located': 121,
#  'by': 122,
#  'people': 123,
#  'truck': 124,
#  'one': 125,
#  'looking': 126,
#  'order': 127,
#  'beanie': 128,
#  'glasses': 129,
#  'leans': 130,
#  'over': 131,
#  'cart': 132,
#  'down': 133,
#  'piece': 134,
#  'paper': 135,
#  'beard': 136,
#  'shirt': 137,
#  'making': 138,
#  'some': 139,
#  'working': 140,
#  'behind': 141,
#  'slides': 142,
#  'pizza': 143,
#  'into': 144,
#  'brick': 145,
#  'wearing': 146,
#  'apron': 147,
#  'next': 148,
#  'to': 149,
#  'ball': 150,
#  'cap': 151,
#  'getting': 152,
#  'ready': 153,
#  'his': 154,
#  'bread': 155,
#  'be': 156,
#  'cutting': 157,
#  'roast': 158,
#  'fork': 159,
#  'knife': 160,
#  'there': 161,
#  'meat': 162,
#  'board': 163,
#  'slicing': 164,
#  'hot': 165,
#  'dark': 166,
#  'several': 167,
#  'room': 168,
#  'counters': 169,
#  'shelves': 170,
#  'filled': 171,
#  'wood': 172,
#  'dishwasher': 173,
#  'sink': 174,
#  'refrigerator': 175,
#  'window': 176,
#  'opened': 177,
#  'appliances': 178,
#  'icebox': 179,
#  'fridge': 180,
#  'microwave': 181,
#  'cook': 182,
#  'under': 183,
#  'lamp': 184,
#  'chief': 185,
#  'plating': 186,
#  'out': 187,
#  'pan': 188,
#  'sous': 189,
#  'adding': 190,
#  'sauce': 191,
#  'plate': 192,
#  'pass': 193,
#  'adults': 194,
#  'laptop': 195,
#  'computers': 196,
#  'while': 197,
#  'sitting': 198,
#  'outdoor': 199,
#  'venue': 200,
#  'row': 201,
#  'men': 202,
#  'laptops': 203,
#  'side': 204,
#  'building': 205,
#  'number': 206,
#  'siting': 207,
#  'bench': 208,
#  'sit': 209,
#  'each': 210,
#  'vegetables': 211,
#  'scallions': 212,
#  'chopping': 213,
#  'stands': 214,
#  'as': 215,
#  'he': 216,
#  'cuts': 217,
#  'onions': 218,
#  'front': 219,
#  'garage': 220,
#  'chefs': 221,
#  'patrons': 222,
#  'exit': 223,
#  'view': 224,
#  'shows': 225,
#  'leaving': 226,
#  'elaborate': 227,
#  'entry': 228,
#  'way': 229,
#  'includes': 230,
#  'curved': 231,
#  'revealing': 232,
#  'work': 233,
#  'features': 234,
#  'see': 235,
#  'walking': 236,
#  'outside': 237,
#  'asian': 238,
#  'dining': 239,
#  'set': 240,
#  'casual': 241,
#  'meal': 242,
#  'flowers': 243,
#  'topped': 244,
#  'four': 245,
#  'place': 246,
#  'mats': 247,
#  'cloth': 248,
#  'vase': 249,
#  'roses': 250,
#  'tablecloth': 251,
#  'placemats': 252,
#  'dinning': 253,
#  'napkins': 254,
#  'cluttered': 255,
#  'but': 256,
#  'clean': 257,
#  'kept': 258,
#  'cramped': 259,
#  'empty': 260,
#  'overhead': 261,
#  'lighting': 262,
#  'home': 263,
#  'bar': 264,
#  'microwaves': 265,
#  'accented': 266,
#  'color': 267,
#  'prepared': 268,
#  'area': 269,
#  'meals': 270,
#  'plated': 271,
#  'dishes': 272,
#  'workers': 273,
#  'commercial': 274,
#  'couple': 275,
#  'bunch': 276,
#  'upcoming': 277,
#  'dinner': 278,
#  'service': 279,
#  'team': 280,
#  'grill': 281,
#  'burgers': 282,
#  'sandwiches': 283,
#  'meats': 284,
#  'being': 285,
#  'made': 286,
#  'laying': 287,
#  'stomach': 288,
#  'towel': 289,
#  'head': 290,
#  'someone': 291,
#  'bed': 292,
#  'photo': 293,
#  'someones': 294,
#  'bare': 295,
#  'lying': 296,
#  'dish': 297,
#  'utensils': 298,
#  'hanging': 299,
#  'from': 300,
#  'strange': 301,
#  'interesting': 302,
#  'curtain': 303,
#  'crowded': 304,
#  'walls': 305,
#  'eating': 306,
#  'noodles': 307,
#  'bowl': 308,
#  'baby': 309,
#  'feeding': 310,
#  'himself': 311,
#  'kid': 312,
#  'spoon': 313,
#  'little': 314,
#  'boy': 315,
#  'help': 316,
#  'own': 317,
#  'hands': 318,
#  'skateboard': 319,
#  'ramp': 320,
#  'doing': 321,
#  'trick': 322,
#  'boys': 323,
#  'skate': 324,
#  'park': 325,
#  'group': 326,
#  'children': 327,
#  'entertaining': 328,
#  'selves': 329,
#  'skatepark': 330,
#  'performs': 331,
#  'tricks': 332,
#  'onlookers': 333,
#  'watch': 334,
#  'steel': 335,
#  'countertops': 336,
#  'stainless': 337,
#  'wit': 338,
#  'ha': 339,
#  'coffee': 340,
#  'make': 341,
#  'corner': 342,
#  'countertop': 343,
#  'field': 344,
#  'talking': 345,
#  'grass': 346,
#  'talks': 347,
#  'cell': 348,
#  'far': 349,
#  'three': 350,
#  'others': 351,
#  'blanket': 352,
#  'light': 353,
#  'colored': 354,
#  'clothing': 355,
#  'tents': 356,
#  'blankent': 357,
#  'cellphone': 358,
#  'lawn': 359,
#  'pair': 360,
#  'tablet': 361,
#  'perched': 362,
#  'laugh': 363,
#  'they': 364,
#  'look': 365,
#  'computer': 366,
#  'smiling': 367,
#  'happily': 368,
#  'plastic': 369,
#  'bottle': 370,
#  'wine': 371,
#  'closeup': 372,
#  'soup': 373,
#  'bowls': 374,
#  'fourths': 375,
#  'corked': 376,
#  'stacks': 377,
#  'pot': 378,
#  'skillet': 379,
#  'dirty': 380,
#  'plates': 381,
#  'bearded': 382,
#  'colorized': 383,
#  'looks': 384,
#  'off': 385,
#  'turned': 386,
#  'observing': 387,
#  'something': 388,
#  'away': 389,
#  'him': 390,
#  'tv': 391,
#  'offering': 392,
#  'taste': 393,
#  'feeds': 394,
#  'bite': 395,
#  'old': 396,
#  'giving': 397,
#  'test': 398,
#  'sample': 399,
#  'her': 400,
#  'fed': 401,
#  'spoonful': 402,
#  'leaves': 403,
#  'training': 404,
#  'wheels': 405,
#  'jumpsuit': 406,
#  'sweater': 407,
#  'picnic': 408,
#  'tricycle': 409,
#  'bath': 410,
#  'ornate': 411,
#  'bathroom': 412,
#  'yellow': 413,
#  'multicolor': 414,
#  'tiles': 415,
#  'decorated': 416,
#  'style': 417,
#  'mediterranean': 418,
#  'mosaic': 419,
#  'tiled': 420,
#  'lot': 421,
#  'fancy': 422,
#  'tile': 423,
#  'tub': 424,
#  'double': 425,
#  'vanity': 426,
#  'chandelier': 427,
#  'intricate': 428,
#  'golden': 429,
#  'bathtub': 430,
#  'ceiling': 431,
#  'green': 432,
#  'mint': 433,
#  'car': 434,
#  'pictures': 435,
#  'washing': 436,
#  'mirror': 437,
#  'crying': 438,
#  'photograph': 439,
#  'toddler': 440,
#  'cries': 441,
#  'dress': 442,
#  'riding': 443,
#  'stand': 444,
#  'everyone': 445,
#  'bikes': 446,
#  'sunglasses': 447,
#  'dog': 448,
#  'street': 449,
#  'solid': 450,
#  'statues': 451,
#  'sidewalk': 452,
#  'post': 453,
#  'monument': 454,
#  'city': 455,
#  'atmosphere': 456,
#  'relaxing': 457,
#  'nearby': 458,
#  'anchored': 459,
#  'between': 460,
#  'parking': 461,
#  'posts': 462,
#  'new': 463,
#  'nothing': 464,
#  'displays': 465,
#  'toilet': 466,
#  'another': 467,
#  'beneath': 468,
#  'reflecting': 469,
#  'roll': 470,
#  'scene': 471,
#  'door': 472,
#  'featuring': 473,
#  'antique': 474,
#  'picture': 475,
#  'brass': 476,
#  'fixtures': 477,
#  'sinks': 478,
#  'mounted': 479,
#  'soap': 480,
#  'pedestal': 481,
#  'public': 482,
#  'restroom': 483,
#  'bottles': 484,
#  'kneeling': 485,
#  'bicycles': 486,
#  'squatting': 487,
#  'taking': 488,
#  'crouching': 489,
#  'ground': 490,
#  'hunkered': 491,
#  'camera': 492,
#  'bright': 493,
#  'loft': 494,
#  'rustic': 495,
#  'windows': 496,
#  '2': 497,
#  'shower': 498,
#  'jacuzzi': 499,
#  'furry': 500,
#  'cat': 501,
#  'pulling': 502,
#  'carpet': 503,
#  'playful': 504,
#  'pulls': 505,
#  'rug': 506,
#  'playing': 507,
#  'around': 508,
#  'upraised': 509,
#  'lid': 510,
#  'bookshelves': 511,
#  'books': 512,
#  'adjacent': 513,
#  'bookshelf': 514,
#  'guy': 515,
#  'hoodie': 516,
#  'peeing': 517,
#  'note': 518,
#  'written': 519,
#  'purple': 520,
#  'urinating': 521,
#  'unfinished': 522,
#  'lined': 523,
#  'crosswalk': 524,
#  'focusing': 525,
#  'bicyclists': 526,
#  'going': 527,
#  'road': 528,
#  'complete': 529,
#  'tab': 530,
#  'plain': 531,
#  'beige': 532,
#  'both': 533,
#  'tub/shower': 534,
#  'destroyed': 535,
#  'mirrored': 536,
#  'cabinet': 537,
#  'run': 538,
#  'paint': 539,
#  'peeling': 540,
#  'need': 541,
#  'remodeling': 542,
#  'repair': 543,
#  'crumbling': 544,
#  'medicine': 545,
#  'abandoned': 546,
#  'peels': 547,
#  'filthy': 548,
#  'floor': 549,
#  'focus': 550,
#  'bow': 551,
#  'toliet': 552,
#  'wrapped': 553,
#  'ribbon': 554,
#  'carefully': 555,
#  'gift-wrapped': 556,
#  'brand': 557,
#  'across': 558,
#  'seat': 559,
#  'groups': 560,
#  'tower': 561,
#  'town': 562,
#  'plaza': 563,
#  'gathered': 564,
#  'square': 565,
#  'strolling': 566,
#  'through': 567,
#  'open': 568,
#  'tools': 569,
#  'demolished': 570,
#  'construction': 571,
#  'torn': 572,
#  'remodeled': 573,
#  'glass': 574,
#  'doors': 575,
#  'clear': 576,
#  'see-through': 577,
#  'grey': 578,
#  'motif': 579,
#  'mirrors': 580,
#  'freshly': 581,
#  'cleaned': 582,
#  'hotel': 583,
#  'closed': 584,
#  'heated': 585,
#  'racks': 586,
#  'built': 587,
#  'hairdryer': 588,
#  'chrome': 589,
#  'sticking': 590,
#  'decently': 591,
#  'sized': 592,
#  'nice': 593,
#  'lights': 594,
#  'decorative': 595,
#  'commode': 596,
#  'marble': 597,
#  'monogrammed': 598,
#  'symbol': 599,
#  'sculpture': 600,
#  'faucet': 601,
#  'porcelain': 602,
#  'reflected': 603,
#  'rectangular': 604,
#  'single': 605,
#  'right': 606,
#  'lady': 607,
#  'van': 608,
#  'seagulls': 609,
#  'landing': 610,
#  'watching': 611,
#  'birds': 612,
#  'automobile': 613,
#  'where': 614,
#  'seagull': 615,
#  'attacking': 616,
#  'roof': 617,
#  'peoples': 618,
#  'sticks': 619,
#  'brown': 620,
#  'puts': 621,
#  'moving': 622,
#  'fluffy': 623,
#  'cute': 624,
#  'school': 625,
#  'bus': 626,
#  'stop': 627,
#  'sign': 628,
#  'sits': 629,
#  'stopped': 630,
#  'showing': 631,
#  'few': 632,
#  'vehicles': 633,
#  'appear': 634,
#  'traveling': 635,
#  'advertisement': 636,
#  'hummer': 637,
#  'ice': 638,
#  'cubes': 639,
#  'bottom': 640,
#  'boat': 641,
#  'lots': 642,
#  'seats': 643,
#  'gate': 644,
#  'bridge': 645,
#  'train': 646,
#  'booths': 647,
#  'phillips': 648,
#  '66': 649,
#  'clocks': 650,
#  'posters': 651,
#  'vintage': 652,
#  'photos': 653,
#  'motorcycle': 654,
#  'displayed': 655,
#  'gas': 656,
#  'station': 657,
#  'logo': 658,
#  'hangs': 659,
#  'underneath': 660,
#  'resembling': 661,
#  'intersection': 662,
#  'roadway': 663,
#  'driving': 664,
#  'cars': 665,
#  'main': 666,
#  'tall': 667,
#  'classic': 668,
#  'chevy': 669,
#  'nomad': 670,
#  'busy': 671,
#  'trash': 672,
#  'can': 673,
#  'simple': 674,
#  'yet': 675,
#  'messy': 676,
#  'garbage': 677,
#  'stall': 678,
#  'pantyhose': 679,
#  'trashcan': 680,
#  'duel': 681,
#  'silver': 682,
#  'faucets': 683,
#  'gray': 684,
#  'lit': 685,
#  'show': 686,
#  'reflection': 687,
#  'urinals': 688,
#  'shaped': 689,
#  'along': 690,
#  'short': 691,
#  'pee': 692,
#  'toilets': 693,
#  'attached': 694,
#  'waterless': 695,
#  'more': 696,
#  'disgusting': 697,
#  'than': 698,
#  'line': 699,
#  'wire': 700,
#  'basket': 701,
#  'transported': 702,
#  'motor': 703,
#  'scooter': 704,
#  'cage': 705,
#  'motocycle': 706,
#  'painted': 707,
#  'rolls': 708,
#  'seen': 709,
#  'slanted': 710,
#  'angle': 711,
#  'napkin': 712,
#  'cup': 713,
#  'arranged': 714,
#  'crossed': 715,
#  'connected': 716,
#  'speaker': 717,
#  'object': 718,
#  'running': 719,
#  'held': 720,
#  'eaten': 721,
#  'mixed': 722,
#  'spoons': 723,
#  'resting': 724,
#  'like': 725,
#  'vases': 726,
#  'ceramic': 727,
#  'fashion': 728,
#  'shown': 729,
#  'floral': 730,
#  'checkered': 731,
#  'done': 732,
#  'flooring': 733,
#  'checker': 734,
#  'pattern': 735,
#  'checked': 736,
#  'overhang': 737,
#  'outdoors': 738,
#  'awning': 739,
#  'stuff': 740,
#  'stored': 741,
#  'structure': 742,
#  'items': 743,
#  'fenced': 744,
#  'yard': 745,
#  'brush': 746,
#  'not': 747,
#  'been': 748,
#  'months': 749,
#  'water': 750,
#  'cleaning': 751,
#  'equipped': 752,
#  'fashionable': 753,
#  'architectural': 754,
#  'subway': 755,
#  'dispensers': 756,
#  'unconventional': 757,
#  'placement': 758,
#  'directly': 759,
#  'below': 760,
#  'horse-drawn': 761,
#  'carriage': 762,
#  'moves': 763,
#  'carrying': 764,
#  'passengers': 765,
#  'horse': 766,
#  'drawn': 767,
#  'ride': 768,
#  'rides': 769,
#  'rails': 770,
#  'handicap': 771,
#  'walk-in': 772,
#  'bathtab': 773,
#  'which': 774,
#  'supplies': 775,
#  'installed': 776,
#  'during': 777,
#  'hole': 778,
#  'd': 779,
#  'pipe': 780,
#  'installations': 781,
#  'motorcycles': 782,
#  'alley': 783,
#  'day': 784,
#  'suzuki': 785,
#  'motorcyles': 786,
#  'behing': 787,
#  'sister': 788,
#  'pants': 789,
#  'kids': 790,
#  'their': 791,
#  'metal': 792,
#  'rail': 793,
#  'airplane': 794,
#  'writing': 795,
#  'demonstration': 796,
#  'needs': 797,
#  'including': 798,
#  'storage': 799,
#  'blown': 800,
#  'broken': 801,
#  'bikers': 802,
#  'trees': 803,
#  'highway': 804,
#  'race': 805,
#  'motorcyclists': 806,
#  'freight': 807,
#  'warehouse': 808,
#  'loading/unloading': 809,
#  'frame': 810,
#  'lift': 811,
#  'maroon': 812,
#  'cruising': 813,
#  'sunny': 814,
#  'alongside': 815,
#  'sun': 816,
#  'churros': 817,
#  'chocolate': 818,
#  'deep': 819,
#  'fried': 820,
#  'melted': 821,
#  'entree': 822,
#  'delicious': 823,
#  'churro': 824,
#  'oval': 825,
#  'platter': 826,
#  'cakes': 827,
#  'donuts': 828,
#  'cake': 829,
#  'brownies': 830,
#  'doughnuts': 831,
#  'trays': 832,
#  'displaying': 833,
#  'multitude': 834,
#  'assorted': 835,
#  'sweet': 836,
#  'treats': 837,
#  'served': 838,
#  'these': 839,
#  'kinds': 840,
#  'helmet': 841,
#  'motorcyclist': 842,
#  'drives': 843,
#  'high': 844,
#  'speeds': 845,
#  'cyclist': 846,
#  'sports': 847,
#  'stuffed': 848,
#  'animal': 849,
#  'platform': 850,
#  'desk': 851,
#  'rock': 852,
#  'dead': 853,
#  'video': 854,
#  'films': 855,
#  'procession': 856,
#  'filming': 857,
#  'scooters': 858,
#  'coming': 859,
#  'passing': 860,
#  'evening': 861,
#  'purpose': 862,
#  'recording': 863,
#  'policeman': 864,
#  'police': 865,
#  'posing': 866,
#  'cop': 867,
#  'or': 868,
#  'officer': 869,
#  'vehicle': 870,
#  'officers': 871,
#  'cops': 872,
#  'uniforms': 873,
#  'strait': 874,
#  'bmw': 875,
#  'leather': 876,
#  'satchel': 877,
#  'event': 878,
#  'function': 879,
#  'formal': 880,
#  'gathering': 881,
#  'takes': 882,
#  'turn': 883,
#  'crowd': 884,
#  'spectators': 885,
#  'curve': 886,
#  'turning': 887,
#  '#': 888,
#  '20': 889,
#  'handle': 890,
#  'bars': 891,
#  'rounding': 892,
#  'employee': 893,
#  'doorway': 894,
#  'passenger': 895,
#  'entrance': 896,
#  'commuter': 897,
#  'cycle': 898,
#  'house': 899,
#  'cans': 900,
#  'umbrella': 901,
#  'shiny': 902,
#  'railing': 903,
#  'porch': 904,
#  'japanese': 905,
#  '``': 906,
#  "''": 907,
#  'lan': 908,
#  'airport': 909,
#  'sea': 910,
#  'jetliner': 911,
#  'runway': 912,
#  'plane': 913,
#  'taxiing': 914,
#  'ruwnay': 915,
#  'jet': 916,
#  'coast': 917,
#  'flying': 918,
#  'air': 919,
#  'flies': 920,
#  'sky': 921,
#  'camouflage': 922,
#  'military': 923,
#  'fighter': 924,
#  'hovering': 925,
#  'clouds': 926,
#  'airplanes': 927,
#  'buildings': 928,
#  'idle': 929,
#  'about': 930,
#  'land': 931,
#  'jumbo': 932,
#  'tarmac': 933,
#  'adorable': 934,
#  'gir': 935,
#  'stone': 936,
#  'plants': 937,
#  'sideways': 938,
#  'shorts': 939,
#  'slippers': 940,
#  'shaded': 941,
#  'layer': 942,
#  'snow': 943,
#  'pole': 944,
#  'traffic': 945,
#  'signal': 946,
#  'thin': 947,
#  'sheep': 948,
#  'roaming': 949,
#  'animals': 950,
#  'grazing': 951,
#  'hillside': 952,
#  'hill': 953,
#  'flock': 954,
#  'graze': 955,
#  'rocky': 956,
#  'kicking': 957,
#  'feet': 958,
#  'holding': 959,
#  'seated': 960,
#  'fence': 961,
#  'covering': 962,
#  'eyes': 963,
#  'giraffe': 964,
#  'nose': 965,
#  'pool': 966,
#  'bending': 967,
#  'drinking': 968,
#  'watering': 969,
#  'drink': 970,
#  'airliner': 971,
#  'cliff': 972,
#  'beside': 973,
#  'plan': 974,
#  'rests': 975,
#  'situated': 976,
#  'mountain': 977,
#  'rolling': 978,
#  'horned': 979,
#  'type': 980,
#  'coat': 981,
#  'bird': 982,
#  'neck': 983,
#  'walk': 984,
#  'background': 985,
#  'propeller': 986,
#  'airshow': 987,
#  'concrete': 988,
#  'feed': 989,
#  'grassy': 990,
#  'struggling': 991,
#  'eat': 992,
#  'low': 993,
#  'pasture': 994,
#  'mountains': 995,
#  'fields': 996,
#  'sheared': 997,
#  'herd': 998,
#  'store': 999,
#  ...}

# %%
len(chartoidx)
# Out:
# 22329

# %%
idxtochar
# Out:
# ['a',
#  'restaurant',
#  'has',
#  'modern',
#  'wooden',
#  'tables',
#  'and',
#  'chairs',
#  '.',
#  'long',
#  'table',
#  'with',
#  'rattan',
#  'rounded',
#  'back',
#  'plant',
#  'on',
#  'top',
#  'of',
#  'it',
#  'surrounded',
#  'flower',
#  'arrangement',
#  'in',
#  'the',
#  'middle',
#  'for',
#  'meetings',
#  'is',
#  'adorned',
#  'blue',
#  'accents',
#  'man',
#  'preparing',
#  'desserts',
#  'kitchen',
#  'covered',
#  'frosting',
#  'chef',
#  'decorating',
#  'many',
#  'small',
#  'pastries',
#  'baker',
#  'prepares',
#  'various',
#  'types',
#  'baked',
#  'goods',
#  'close',
#  'up',
#  'person',
#  'grabbing',
#  'pastry',
#  'container',
#  'hand',
#  'touching',
#  'big',
#  'red',
#  'telephone',
#  'booth',
#  'that',
#  'standing',
#  'inside',
#  'phone',
#  'this',
#  'an',
#  'image',
#  'using',
#  'full',
#  'spices',
#  'rack',
#  'counter',
#  ',',
#  'oven',
#  'other',
#  'accessories',
#  'utilizes',
#  'all',
#  'its',
#  'space',
#  'pots',
#  'pans',
#  'display',
#  'very',
#  'stove',
#  'shelf',
#  'child',
#  'woman',
#  'are',
#  'cooking',
#  'glances',
#  'at',
#  'young',
#  'girl',
#  "'s",
#  'stovetop',
#  'food',
#  'older',
#  'two',
#  'women',
#  'together',
#  'huge',
#  'clock',
#  'wall',
#  'near',
#  'large',
#  'face',
#  'numbers',
#  'end',
#  'above',
#  'radiator',
#  'bicycle',
#  'parked',
#  'cabinets',
#  'black',
#  'leaning',
#  'against',
#  'white',
#  'bike',
#  'backpack',
#  'located',
#  'by',
#  'people',
#  'truck',
#  'one',
#  'looking',
#  'order',
#  'beanie',
#  'glasses',
#  'leans',
#  'over',
#  'cart',
#  'down',
#  'piece',
#  'paper',
#  'beard',
#  'shirt',
#  'making',
#  'some',
#  'working',
#  'behind',
#  'slides',
#  'pizza',
#  'into',
#  'brick',
#  'wearing',
#  'apron',
#  'next',
#  'to',
#  'ball',
#  'cap',
#  'getting',
#  'ready',
#  'his',
#  'bread',
#  'be',
#  'cutting',
#  'roast',
#  'fork',
#  'knife',
#  'there',
#  'meat',
#  'board',
#  'slicing',
#  'hot',
#  'dark',
#  'several',
#  'room',
#  'counters',
#  'shelves',
#  'filled',
#  'wood',
#  'dishwasher',
#  'sink',
#  'refrigerator',
#  'window',
#  'opened',
#  'appliances',
#  'icebox',
#  'fridge',
#  'microwave',
#  'cook',
#  'under',
#  'lamp',
#  'chief',
#  'plating',
#  'out',
#  'pan',
#  'sous',
#  'adding',
#  'sauce',
#  'plate',
#  'pass',
#  'adults',
#  'laptop',
#  'computers',
#  'while',
#  'sitting',
#  'outdoor',
#  'venue',
#  'row',
#  'men',
#  'laptops',
#  'side',
#  'building',
#  'number',
#  'siting',
#  'bench',
#  'sit',
#  'each',
#  'vegetables',
#  'scallions',
#  'chopping',
#  'stands',
#  'as',
#  'he',
#  'cuts',
#  'onions',
#  'front',
#  'garage',
#  'chefs',
#  'patrons',
#  'exit',
#  'view',
#  'shows',
#  'leaving',
#  'elaborate',
#  'entry',
#  'way',
#  'includes',
#  'curved',
#  'revealing',
#  'work',
#  'features',
#  'see',
#  'walking',
#  'outside',
#  'asian',
#  'dining',
#  'set',
#  'casual',
#  'meal',
#  'flowers',
#  'topped',
#  'four',
#  'place',
#  'mats',
#  'cloth',
#  'vase',
#  'roses',
#  'tablecloth',
#  'placemats',
#  'dinning',
#  'napkins',
#  'cluttered',
#  'but',
#  'clean',
#  'kept',
#  'cramped',
#  'empty',
#  'overhead',
#  'lighting',
#  'home',
#  'bar',
#  'microwaves',
#  'accented',
#  'color',
#  'prepared',
#  'area',
#  'meals',
#  'plated',
#  'dishes',
#  'workers',
#  'commercial',
#  'couple',
#  'bunch',
#  'upcoming',
#  'dinner',
#  'service',
#  'team',
#  'grill',
#  'burgers',
#  'sandwiches',
#  'meats',
#  'being',
#  'made',
#  'laying',
#  'stomach',
#  'towel',
#  'head',
#  'someone',
#  'bed',
#  'photo',
#  'someones',
#  'bare',
#  'lying',
#  'dish',
#  'utensils',
#  'hanging',
#  'from',
#  'strange',
#  'interesting',
#  'curtain',
#  'crowded',
#  'walls',
#  'eating',
#  'noodles',
#  'bowl',
#  'baby',
#  'feeding',
#  'himself',
#  'kid',
#  'spoon',
#  'little',
#  'boy',
#  'help',
#  'own',
#  'hands',
#  'skateboard',
#  'ramp',
#  'doing',
#  'trick',
#  'boys',
#  'skate',
#  'park',
#  'group',
#  'children',
#  'entertaining',
#  'selves',
#  'skatepark',
#  'performs',
#  'tricks',
#  'onlookers',
#  'watch',
#  'steel',
#  'countertops',
#  'stainless',
#  'wit',
#  'ha',
#  'coffee',
#  'make',
#  'corner',
#  'countertop',
#  'field',
#  'talking',
#  'grass',
#  'talks',
#  'cell',
#  'far',
#  'three',
#  'others',
#  'blanket',
#  'light',
#  'colored',
#  'clothing',
#  'tents',
#  'blankent',
#  'cellphone',
#  'lawn',
#  'pair',
#  'tablet',
#  'perched',
#  'laugh',
#  'they',
#  'look',
#  'computer',
#  'smiling',
#  'happily',
#  'plastic',
#  'bottle',
#  'wine',
#  'closeup',
#  'soup',
#  'bowls',
#  'fourths',
#  'corked',
#  'stacks',
#  'pot',
#  'skillet',
#  'dirty',
#  'plates',
#  'bearded',
#  'colorized',
#  'looks',
#  'off',
#  'turned',
#  'observing',
#  'something',
#  'away',
#  'him',
#  'tv',
#  'offering',
#  'taste',
#  'feeds',
#  'bite',
#  'old',
#  'giving',
#  'test',
#  'sample',
#  'her',
#  'fed',
#  'spoonful',
#  'leaves',
#  'training',
#  'wheels',
#  'jumpsuit',
#  'sweater',
#  'picnic',
#  'tricycle',
#  'bath',
#  'ornate',
#  'bathroom',
#  'yellow',
#  'multicolor',
#  'tiles',
#  'decorated',
#  'style',
#  'mediterranean',
#  'mosaic',
#  'tiled',
#  'lot',
#  'fancy',
#  'tile',
#  'tub',
#  'double',
#  'vanity',
#  'chandelier',
#  'intricate',
#  'golden',
#  'bathtub',
#  'ceiling',
#  'green',
#  'mint',
#  'car',
#  'pictures',
#  'washing',
#  'mirror',
#  'crying',
#  'photograph',
#  'toddler',
#  'cries',
#  'dress',
#  'riding',
#  'stand',
#  'everyone',
#  'bikes',
#  'sunglasses',
#  'dog',
#  'street',
#  'solid',
#  'statues',
#  'sidewalk',
#  'post',
#  'monument',
#  'city',
#  'atmosphere',
#  'relaxing',
#  'nearby',
#  'anchored',
#  'between',
#  'parking',
#  'posts',
#  'new',
#  'nothing',
#  'displays',
#  'toilet',
#  'another',
#  'beneath',
#  'reflecting',
#  'roll',
#  'scene',
#  'door',
#  'featuring',
#  'antique',
#  'picture',
#  'brass',
#  'fixtures',
#  'sinks',
#  'mounted',
#  'soap',
#  'pedestal',
#  'public',
#  'restroom',
#  'bottles',
#  'kneeling',
#  'bicycles',
#  'squatting',
#  'taking',
#  'crouching',
#  'ground',
#  'hunkered',
#  'camera',
#  'bright',
#  'loft',
#  'rustic',
#  'windows',
#  '2',
#  'shower',
#  'jacuzzi',
#  'furry',
#  'cat',
#  'pulling',
#  'carpet',
#  'playful',
#  'pulls',
#  'rug',
#  'playing',
#  'around',
#  'upraised',
#  'lid',
#  'bookshelves',
#  'books',
#  'adjacent',
#  'bookshelf',
#  'guy',
#  'hoodie',
#  'peeing',
#  'note',
#  'written',
#  'purple',
#  'urinating',
#  'unfinished',
#  'lined',
#  'crosswalk',
#  'focusing',
#  'bicyclists',
#  'going',
#  'road',
#  'complete',
#  'tab',
#  'plain',
#  'beige',
#  'both',
#  'tub/shower',
#  'destroyed',
#  'mirrored',
#  'cabinet',
#  'run',
#  'paint',
#  'peeling',
#  'need',
#  'remodeling',
#  'repair',
#  'crumbling',
#  'medicine',
#  'abandoned',
#  'peels',
#  'filthy',
#  'floor',
#  'focus',
#  'bow',
#  'toliet',
#  'wrapped',
#  'ribbon',
#  'carefully',
#  'gift-wrapped',
#  'brand',
#  'across',
#  'seat',
#  'groups',
#  'tower',
#  'town',
#  'plaza',
#  'gathered',
#  'square',
#  'strolling',
#  'through',
#  'open',
#  'tools',
#  'demolished',
#  'construction',
#  'torn',
#  'remodeled',
#  'glass',
#  'doors',
#  'clear',
#  'see-through',
#  'grey',
#  'motif',
#  'mirrors',
#  'freshly',
#  'cleaned',
#  'hotel',
#  'closed',
#  'heated',
#  'racks',
#  'built',
#  'hairdryer',
#  'chrome',
#  'sticking',
#  'decently',
#  'sized',
#  'nice',
#  'lights',
#  'decorative',
#  'commode',
#  'marble',
#  'monogrammed',
#  'symbol',
#  'sculpture',
#  'faucet',
#  'porcelain',
#  'reflected',
#  'rectangular',
#  'single',
#  'right',
#  'lady',
#  'van',
#  'seagulls',
#  'landing',
#  'watching',
#  'birds',
#  'automobile',
#  'where',
#  'seagull',
#  'attacking',
#  'roof',
#  'peoples',
#  'sticks',
#  'brown',
#  'puts',
#  'moving',
#  'fluffy',
#  'cute',
#  'school',
#  'bus',
#  'stop',
#  'sign',
#  'sits',
#  'stopped',
#  'showing',
#  'few',
#  'vehicles',
#  'appear',
#  'traveling',
#  'advertisement',
#  'hummer',
#  'ice',
#  'cubes',
#  'bottom',
#  'boat',
#  'lots',
#  'seats',
#  'gate',
#  'bridge',
#  'train',
#  'booths',
#  'phillips',
#  '66',
#  'clocks',
#  'posters',
#  'vintage',
#  'photos',
#  'motorcycle',
#  'displayed',
#  'gas',
#  'station',
#  'logo',
#  'hangs',
#  'underneath',
#  'resembling',
#  'intersection',
#  'roadway',
#  'driving',
#  'cars',
#  'main',
#  'tall',
#  'classic',
#  'chevy',
#  'nomad',
#  'busy',
#  'trash',
#  'can',
#  'simple',
#  'yet',
#  'messy',
#  'garbage',
#  'stall',
#  'pantyhose',
#  'trashcan',
#  'duel',
#  'silver',
#  'faucets',
#  'gray',
#  'lit',
#  'show',
#  'reflection',
#  'urinals',
#  'shaped',
#  'along',
#  'short',
#  'pee',
#  'toilets',
#  'attached',
#  'waterless',
#  'more',
#  'disgusting',
#  'than',
#  'line',
#  'wire',
#  'basket',
#  'transported',
#  'motor',
#  'scooter',
#  'cage',
#  'motocycle',
#  'painted',
#  'rolls',
#  'seen',
#  'slanted',
#  'angle',
#  'napkin',
#  'cup',
#  'arranged',
#  'crossed',
#  'connected',
#  'speaker',
#  'object',
#  'running',
#  'held',
#  'eaten',
#  'mixed',
#  'spoons',
#  'resting',
#  'like',
#  'vases',
#  'ceramic',
#  'fashion',
#  'shown',
#  'floral',
#  'checkered',
#  'done',
#  'flooring',
#  'checker',
#  'pattern',
#  'checked',
#  'overhang',
#  'outdoors',
#  'awning',
#  'stuff',
#  'stored',
#  'structure',
#  'items',
#  'fenced',
#  'yard',
#  'brush',
#  'not',
#  'been',
#  'months',
#  'water',
#  'cleaning',
#  'equipped',
#  'fashionable',
#  'architectural',
#  'subway',
#  'dispensers',
#  'unconventional',
#  'placement',
#  'directly',
#  'below',
#  'horse-drawn',
#  'carriage',
#  'moves',
#  'carrying',
#  'passengers',
#  'horse',
#  'drawn',
#  'ride',
#  'rides',
#  'rails',
#  'handicap',
#  'walk-in',
#  'bathtab',
#  'which',
#  'supplies',
#  'installed',
#  'during',
#  'hole',
#  'd',
#  'pipe',
#  'installations',
#  'motorcycles',
#  'alley',
#  'day',
#  'suzuki',
#  'motorcyles',
#  'behing',
#  'sister',
#  'pants',
#  'kids',
#  'their',
#  'metal',
#  'rail',
#  'airplane',
#  'writing',
#  'demonstration',
#  'needs',
#  'including',
#  'storage',
#  'blown',
#  'broken',
#  'bikers',
#  'trees',
#  'highway',
#  'race',
#  'motorcyclists',
#  'freight',
#  'warehouse',
#  'loading/unloading',
#  'frame',
#  'lift',
#  'maroon',
#  'cruising',
#  'sunny',
#  'alongside',
#  'sun',
#  'churros',
#  'chocolate',
#  'deep',
#  'fried',
#  'melted',
#  'entree',
#  'delicious',
#  'churro',
#  'oval',
#  'platter',
#  'cakes',
#  'donuts',
#  'cake',
#  'brownies',
#  'doughnuts',
#  'trays',
#  'displaying',
#  'multitude',
#  'assorted',
#  'sweet',
#  'treats',
#  'served',
#  'these',
#  'kinds',
#  'helmet',
#  'motorcyclist',
#  'drives',
#  'high',
#  'speeds',
#  'cyclist',
#  'sports',
#  'stuffed',
#  'animal',
#  'platform',
#  'desk',
#  'rock',
#  'dead',
#  'video',
#  'films',
#  'procession',
#  'filming',
#  'scooters',
#  'coming',
#  'passing',
#  'evening',
#  'purpose',
#  'recording',
#  'policeman',
#  'police',
#  'posing',
#  'cop',
#  'or',
#  'officer',
#  'vehicle',
#  'officers',
#  'cops',
#  'uniforms',
#  'strait',
#  'bmw',
#  'leather',
#  'satchel',
#  'event',
#  'function',
#  'formal',
#  'gathering',
#  'takes',
#  'turn',
#  'crowd',
#  'spectators',
#  'curve',
#  'turning',
#  '#',
#  '20',
#  'handle',
#  'bars',
#  'rounding',
#  'employee',
#  'doorway',
#  'passenger',
#  'entrance',
#  'commuter',
#  'cycle',
#  'house',
#  'cans',
#  'umbrella',
#  'shiny',
#  'railing',
#  'porch',
#  'japanese',
#  '``',
#  "''",
#  'lan',
#  'airport',
#  'sea',
#  'jetliner',
#  'runway',
#  'plane',
#  'taxiing',
#  'ruwnay',
#  'jet',
#  'coast',
#  'flying',
#  'air',
#  'flies',
#  'sky',
#  'camouflage',
#  'military',
#  'fighter',
#  'hovering',
#  'clouds',
#  'airplanes',
#  'buildings',
#  'idle',
#  'about',
#  'land',
#  'jumbo',
#  'tarmac',
#  'adorable',
#  'gir',
#  'stone',
#  'plants',
#  'sideways',
#  'shorts',
#  'slippers',
#  'shaded',
#  'layer',
#  'snow',
#  'pole',
#  'traffic',
#  'signal',
#  'thin',
#  'sheep',
#  'roaming',
#  'animals',
#  'grazing',
#  'hillside',
#  'hill',
#  'flock',
#  'graze',
#  'rocky',
#  'kicking',
#  'feet',
#  'holding',
#  'seated',
#  'fence',
#  'covering',
#  'eyes',
#  'giraffe',
#  'nose',
#  'pool',
#  'bending',
#  'drinking',
#  'watering',
#  'drink',
#  'airliner',
#  'cliff',
#  'beside',
#  'plan',
#  'rests',
#  'situated',
#  'mountain',
#  'rolling',
#  'horned',
#  'type',
#  'coat',
#  'bird',
#  'neck',
#  'walk',
#  'background',
#  'propeller',
#  'airshow',
#  'concrete',
#  'feed',
#  'grassy',
#  'struggling',
#  'eat',
#  'low',
#  'pasture',
#  'mountains',
#  'fields',
#  'sheared',
#  'herd',
#  'store',
#  ...]

# %%
# glove_embedding = torchtext.vocab.GloVe(name='6B', dim='300')
idxtochar = idxtochar + ['<unk>','<start>','<end>']
chartoidx.update({'<unk>':22329,
                         '<start>':22330,
                         '<end>':22331})
print(len(chartoidx))
# Out:
# 22332

# %%
def stoi(captions_list):
    caption_token_list = []
    for caption in captions_list:
        tokens_list = [chartoidx['<start>']] + []
        for token in caption:
            try:
                tokens_list.append(chartoidx[token])
            except:
                tokens_list.append(chartoidx['<unk>'])
        tokens_list = tokens_list + [chartoidx['<end>']]
        caption_token_list.append(tokens_list)
    return caption_token_list

image_captions_df['idx_tokens'] = image_captions_df['tokens'].apply(lambda x : stoi(x))
image_captions_df
# Out:
#        image_id                        file_name  \
# 0         57870  COCO_train2014_000000057870.jpg
# 1        384029  COCO_train2014_000000384029.jpg
# 2        222016  COCO_train2014_000000222016.jpg
# 3        520950  COCO_train2014_000000520950.jpg
# 4         69675  COCO_train2014_000000069675.jpg
# ...         ...                              ...
# 66658    360271  COCO_train2014_000000360271.jpg
# 66659    471345  COCO_train2014_000000471345.jpg
# 66660    444010  COCO_train2014_000000444010.jpg
# 66661    565004  COCO_train2014_000000565004.jpg
# 66662    516168  COCO_train2014_000000516168.jpg
#
#                                                 captions  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66659  [[a, table, topped, with, two, white, plates, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                        caption_token_set  \
# 0      [arrangement, is, flower, on, table, blue, top...
# 1      [types, desserts, person, is, kitchen, many, u...
# 2      [inside, person, image, standing, is, an, that...
# 3      [is, on, that, kitchen, all, utilizes, with, i...
# 4      [child, woman, person, on, women, an, together...
# ...                                                  ...
# 66658  [woman, another, dinner., sitting, is, watchin...
# 66659  [lobster,, rice., sitting, is, on, table, sit,...
# 66660  [woman, jovial, sitting, table, group, togethe...
# 66661  [another, is, on, table, wine, with, red, glas...
# 66662  [paper, glases, standing, is, sitting, on, tab...
#
#                                             idx_captions  \
# 0      [[27, 13, 25, 23, 9, 30, 12, 19], [27, 22, 13,...
# 1      [[27, 53, 56, 33, 29, 27, 35, 42, 29, 50], [27...
# 2      [[27, 66, 62, 67, 65, 61, 27, 53, 1, 59, 29], ...
# 3      [[20, 35, 1, 73, 28, 80, 3, 20, 75], [27, 35, ...
# 4      [[27, 88, 12, 89, 94, 98, 29, 20, 99], [27, 89...
# ...                                                  ...
# 66658  [[90, 215, 102, 27, 311, 4, 7, 140, 145, 102, ...
# 66659  [[27, 4, 283, 7, 103, 118, 427, 28, 97, 163, 1...
# 66660  [[27, 362, 28, 2829, 215, 144, 102, 27, 4, 330...
# 66661  [[418, 319, 6776, 161, 27, 686, 139, 27, 4], [...
# 66662  [[27, 53, 1, 59, 135, 27, 3694, 7, 15795], [27...
#
#                                                   tokens  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66659  [[a, table, topped, with, two, white, plates, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                               idx_tokens
# 0      [[22330, 0, 1, 2, 3, 4, 5, 6, 7, 8, 22331], [2...
# 1      [[22330, 0, 32, 33, 34, 23, 0, 35, 36, 23, 37,...
# 2      [[22330, 0, 57, 58, 59, 60, 61, 0, 32, 28, 62,...
# 3      [[22330, 24, 35, 28, 69, 18, 70, 16, 24, 71, 2...
# 4      [[22330, 0, 87, 6, 88, 89, 90, 23, 24, 35, 8, ...
# ...                                                  ...
# 66658  [[22330, 100, 198, 92, 0, 278, 10, 11, 125, 12...
# 66659  [[22330, 0, 10, 244, 11, 99, 118, 381, 18, 97,...
# 66660  [[22330, 0, 326, 18, 2253, 198, 133, 92, 0, 10...
# 66661  [[22330, 371, 285, 5020, 144, 0, 574, 131, 0, ...
# 66662  [[22330, 0, 32, 28, 62, 141, 0, 264, 11, 11053...
#
# [66663 rows x 7 columns]

# %%
# def stoi(captions_list):
#     caption_token_list = []
#     for caption in captions_list:
#         tokens_list = []
#         for token in caption:
#             try:
#                 tokens_list.append(chartoidx[token])
#             except:
#                 tokens_list.append(chartoidx['<unk>'])
#         # tokens_list = tokens_list + [glove_embedding.stoi['<end>']]
#         caption_token_list.append(tokens_list)
#     return caption_token_list

# image_captions_df['idx_tokens'] = image_captions_df['tokens'].apply(lambda x : stoi(x))
# image_captions_df

# %%
image_captions_df['idx_tokens'][0]
# Out:
# [[22330, 0, 1, 2, 3, 4, 5, 6, 7, 8, 22331],
#  [22330, 0, 9, 1, 10, 11, 12, 13, 14, 7, 8, 22331],
#  [22330, 0, 9, 10, 11, 0, 15, 16, 17, 18, 19, 20, 11, 4, 7, 22331],
#  [22330, 0, 9, 10, 11, 0, 21, 22, 23, 24, 25, 26, 27, 22331],
#  [22330, 0, 10, 28, 29, 11, 4, 7, 11, 30, 31, 8, 22331]]

# %%
# # we would also need to define the <unk>, <strart> and <end> token embeddings as a vector of zeros.
# unk_vector = torch.zeros(1,300)
# start_vector = torch.zeros(1,300)
# end_vector = torch.zeros(1,300)

# glove_embedding.vectors = torch.cat((glove_embedding.vectors, unk_vector, start_vector, end_vector), dim = 0)
# print(glove_embedding.vectors.shape)

# %%
# glove_embedding.vectors.shape

# %%
manual_transforms = Compose([
                            Resize(size = (256,256)),
                            CenterCrop(size=(224,224)),
                            Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

# %% [markdown]
# ##### Now lets define the dataloader which would take in

# %% [markdown]
# #### We would add the start token seperately and also the end token at the end

# %%
class CocoDataset(Dataset):
    def __init__(self,image_label_df, val_stride = 10, is_val_set_bool = False, test_data_set =False, test_stride = 5, transforms = None):
        
        self.transfrom = transforms
        self.is_val_set_bool = is_val_set_bool
        self.val_stride = val_stride
        self.image_label_df = image_label_df.copy()
        self.test_data_set = test_data_set
        self.test_stride = test_stride

        if self.test_data_set: #If we need only a small subset of the data to work with
            self.image_label_df = self.image_label_df[::test_stride].reset_index(drop = True)

        elif self.is_val_set_bool: # If we need only the validation data then return the validation data which is a subset of total data
            assert self.val_stride > 0
            self.image_label_df = self.image_label_df[::val_stride]

        elif self.val_stride > 0:  # Else if val_stride is greater than zero then return the remaining dataframe after removing 10% of data
            self.image_label_df = self.image_label_df.drop(index = list(range(0,len(self.image_label_df),self.val_stride)))
            
        else: # else train on the full dataset
            self.image_label_df = self.image_label_df
        
    def __len__(self):
        """ This method calculates the length of your data."""
        return len(self.image_label_df)

    # Now we will introduce function which gives us an image and its corresponding labels by id
    def get_image_by_id(self, img_id = None):
        """ This function returns an image by its id and the corresponding multiple labesl in a present/no_present binary format"""
        

        folder_path = 'F://coco/train2014/train2014/'

        if img_id == None:
            raise ValueError('Must provide IMAGE ID')

        else:
            row = self.image_label_df[self.image_label_df['image_id']==img_id]
            file_name = row['file_name'].values[0]

            captions_array = torch.tensor(row['idx_tokens'][0][0])

            # Get the image-data from file_name
            image_array = torchvision.io.read_image(folder_path + file_name)
            image_array = (image_array/255.0).to(torch.float32)
            image_array = self.transfrom(image_array).to(torch.float32)
        
            return image_array, captions_array


    # Now we would write the code for returning the image from index and its corresponding labels. Which would be used by the train/val dataloaders
    def __getitem__(self, ndx):

        """ This function takes in an index and returns the image and the labels of the image at that index"""
        folder_path = 'F://coco/train2014/train2014/'
        
        row = self.image_label_df.iloc[ndx]
        # print(row)

        # Now get the image_id and the file_name of the image
        image_id = row['image_id']
        file_name = row['file_name']
        
        # Now get the captions array from the dataframe
        captions_array = torch.tensor(row['idx_tokens'][0])
        # Now get the image_data from storage
        image_array = torchvision.io.read_image(folder_path + file_name)
        image_array = (image_array/255.0).to(torch.float32)
        image_array = self.transfrom(image_array).to(torch.float32)
        # print(captions_array)
        return (image_array, captions_array, image_id)

# %%
# Create the datasets
# train_coco = CocoDataset(image_label_df=image_label_df, val_stride=10, transforms=manual_transforms)
val_coco = CocoDataset(image_label_df=image_captions_df,is_val_set_bool=True, val_stride=200, transforms=manual_transforms)

# Create the dataloaders
# train_dataloader = DataLoader(dataset=train_coco, batch_size=128, pin_memory=True, drop_last=True, num_workers=4)
val_dataloader = DataLoader(dataset=val_coco, batch_size=1,pin_memory=True, drop_last = True)

# create a test dataset and a dataloader
test_coco = CocoDataset(image_label_df=image_captions_df, test_data_set=True, test_stride=50, transforms=manual_transforms)

test_coco_dataloader = DataLoader(dataset=test_coco, batch_size=1, pin_memory =  True,drop_last=True)

# %%
print(len(test_coco), len(val_coco))
# Out:
# 1334 334

# %%
val_coco[0]
# Out:
# (tensor([[[ 1.9845,  2.0282,  2.1066,  ..., -1.5453, -1.4803, -1.4329],
#           [ 2.0787,  2.1186,  2.1630,  ..., -1.5129, -1.5295, -1.3770],
#           [ 2.1288,  2.1801,  2.2007,  ..., -1.5440, -1.5506, -1.3885],
#           ...,
#           [-0.8186, -0.9293, -1.2151,  ...,  1.1449,  1.2222,  1.1112],
#           [-0.6762, -0.9331, -1.2721,  ...,  1.2070,  1.0772,  1.0296],
#           [-0.9186, -0.8472, -1.1707,  ...,  1.1230,  0.9924,  1.0074]],
#
#          [[ 1.4887,  1.5653,  1.6484,  ..., -1.5204, -1.5866, -1.5113],
#           [ 1.5893,  1.6470,  1.7540,  ..., -1.5135, -1.5127, -1.5059],
#           [ 1.6629,  1.7494,  1.8205,  ..., -1.5403, -1.5721, -1.5089],
#           ...,
#           [-1.5387, -1.5428, -1.6320,  ...,  1.4164,  1.5767,  1.4394],
#           [-1.5362, -1.5023, -1.5565,  ...,  1.5152,  1.3464,  1.2955],
#           [-1.3907, -1.5480, -1.5731,  ...,  1.5051,  1.3453,  1.2162]],
#
#          [[ 0.9374,  0.8916,  1.0398,  ..., -1.2865, -1.2206, -1.2715],
#           [ 0.9505,  0.9995,  1.0825,  ..., -1.2421, -1.2148, -1.2298],
#           [ 0.9622,  1.0594,  1.1498,  ..., -1.3093, -1.2048, -1.2603],
#           ...,
#           [-1.7369, -1.5738, -1.6620,  ...,  2.5869,  2.5992,  2.5899],
#           [-1.3750, -1.7236, -1.6854,  ...,  2.5207,  2.4834,  2.5896],
#           [-1.3431, -1.6244, -1.6013,  ...,  2.6326,  2.5245,  2.5520]]]),
#  tensor([22330,     0,     1,     2,     3,     4,     5,     6,     7,     8,
#          22331]),
#  57870)

# %% [markdown]
# ##### Now we have created our test and val dataloaders. Now is the time to create the full convnet+RNN model

# %%
class CustomResNet(nn.Module):
    def __init__(self, pretrained_model = None):
        super().__init__()



        for parameter in pretrained_model.parameters():
            parameter.requires_grad = False

        
        pretrained_model.fc = nn.Linear(2048,256)

        
        self.backbone = nn.Sequential(pretrained_model)
        # Till the previous step we have a pretrained Resnet whose weights we have frozen. Now we will define the RNN

        # self.embedding_matrix = torch.randn(len(chartoidx), 50, requires_grad=True) / (len(chartoidx)**0.5)
        self.embedding_matrix = nn.Embedding(len(chartoidx), 50)
        self.rnn = nn.RNNCell(input_size=50, hidden_size = 256, nonlinearity='tanh')
        self.output_layer = nn.Linear(256,len(chartoidx))

        self.cross_entopy_loss = nn.CrossEntropyLoss()

    def forward(self, image, caption_list):
        out_backbone = self.backbone(image)

        hidden = out_backbone.squeeze(0)
        # print(f"the hidden shape from image is {hidden.shape}")
        i = 0
        # new_char_id = char_id
        loss_word_list = []
        current_word_id = caption_list[i]
        target_index = caption_list[i+1]
        while True:
            
            if i == 0:
                current_word_id = caption_list[0]
            target_index = caption_list[i+1]
            if idxtochar[target_index] == '<end>':
                break
            out_embedding = self.embedding_matrix(current_word_id)  # embedding_shape = (1,50)
            # print(out_embedding.shape)
            # print(out_embedding, out_embedding.requires_grad)
            # print(f"The out embedding shape is {out_embedding.shape}")
            # calculate the hidden state activation from the embedding and the previous hidden state and get the next hidden state
            hidden = self.rnn(out_embedding, hidden)   # hidden_shape = (1,1024)

            # Now dish out the output_logits of the current time step
            output_logits = self.output_layer(hidden)   # output_logits shape (1,len(vocab))
            # print(f"The shape of output logits is {output_logits.shape}")

            # # calculate the probabilities of the characters
            probs =  torch.softmax(output_logits, dim = 0)         # probs_shape = (1,len(vocab))

            # print(f"The shape of probs is {probs.shape}")
            # print(f"The shape of output probabilities is {probs.shape}")
            # # Now get the index of the larget probability.
            next_word_id = torch.argmax(probs, dim =0)
            # print(f"the next word id  is {idxtochar[next_word_id.item()]}, and id is {next_word_id.item()}")

            # Now we will take the next_word that the cell thinks will be and do two things.
            # First we use it and the target to calculate the loss
            current_word_loss = self.cross_entopy_loss(probs, caption_list[i+1])
            # append the current_word_loss to loss_word_list
            loss_word_list.append(current_word_loss)
            
            # Second we would use the index of the current most probable output word as an input of the next time-step
            current_word_id = next_word_id
            # increase the value of i by 1 so that we can get the target word for the next input word
            i+=1
            
        final_loss = torch.sum(torch.tensor(loss_word_list, requires_grad=True))
        return final_loss

# %%
res_50 = torchvision.models.resnet50(weights =ResNet50_Weights.DEFAULT)
cust_res = CustomResNet(pretrained_model=res_50)

# %%
print(cust_res)
# Out:
# CustomResNet(
#   (backbone): Sequential(
#     (0): ResNet(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#       (fc): Linear(in_features=2048, out_features=256, bias=True)
#     )
#   )
#   (embedding_matrix): Embedding(22332, 50)
#   (rnn): RNNCell(50, 256)
#   (output_layer): Linear(in_features=256, out_features=22332, bias=True)
#   (cross_entopy_loss): CrossEntropyLoss()
# )

# %%
summary(cust_res)
# Out:
# ===========================================================================
# Layer (type:depth-idx)                             Param #
# ===========================================================================
# CustomResNet                                       --
# ├─Sequential: 1-1                                  --
# │    └─ResNet: 2-1                                 --
# │    │    └─Conv2d: 3-1                            (9,408)
# │    │    └─BatchNorm2d: 3-2                       (128)
# │    │    └─ReLU: 3-3                              --
# │    │    └─MaxPool2d: 3-4                         --
# │    │    └─Sequential: 3-5                        (215,808)
# │    │    └─Sequential: 3-6                        (1,219,584)
# │    │    └─Sequential: 3-7                        (7,098,368)
# │    │    └─Sequential: 3-8                        (14,964,736)
# │    │    └─AdaptiveAvgPool2d: 3-9                 --
# │    │    └─Linear: 3-10                           524,544
# ├─Embedding: 1-2                                   1,116,600
# ├─RNNCell: 1-3                                     78,848
# ├─Linear: 1-4                                      5,739,324
# ├─CrossEntropyLoss: 1-5                            --
# ===========================================================================
# Total params: 30,967,348
# Trainable params: 7,459,316
# Non-trainable params: 23,508,032
# ===========================================================================

# %%
# from tqdm.notebook import tqdm_notebook
# for i in range(1):
#     for image_batch, caption_batch, _ in tqdm_notebook(test_coco_dataloader):
#         image_batch.shape, caption_batch.shape
#     break

# %%
# Now lets create the training loop which would take in the image and the caption train on it word by word
def training_loop(epochs, train_dataloader, val_dataloader, model, optimizer):
    for epoch in range(epochs):
        loss_list = []
        for batch in tqdm(train_dataloader):
            image, caption, _ = batch
            # print(image.shape)
            # image = torch.unsqueeze(image, dim=0)
            # print(caption.shape)
            # image = image.to(device = torch.device('cuda')),.,
            # caption = caption.to(device = torch.device('cuda'))
            optimizer.zero_grad()
            output =  model(image, caption[0])
            # print(output, grad_info)
            # break
            loss_list.append(output.item())
            output.backward()
            # print(grad_b)
            optimizer.step()
            # print(output.item())
        print(f"The loss is {sum(loss_list)/len(loss_list)}")

# %%
adam_optimizer = optim.Adam(cust_res.parameters(), lr  = 3e-2)
training_loop(10, train_dataloader=test_coco_dataloader, val_dataloader=None, model = cust_res, optimizer=adam_optimizer)
# Out:
# 100%|██████████| 1334/1334 [06:41<00:00,  3.32it/s]
# The loss is 112.8016164513721
# 100%|██████████| 1334/1334 [05:05<00:00,  4.36it/s]
# The loss is 112.8016164513721
# 100%|██████████| 1334/1334 [04:59<00:00,  4.45it/s]
# The loss is 112.8016164513721
#   1%|          | 9/1334 [00:02<06:16,  3.51it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 2
#       1 adam_optimizer = optim.Adam(cust_res.parameters(), lr  = 3e-2)
# ----> 2 training_loop(10, train_dataloader=test_coco_dataloader, val_dataloader=None, model = cust_res, optimizer=adam_optimizer)
#
# Cell In[54], line 13, in training_loop(epochs, train_dataloader, val_dataloader, model, optimizer)
#       7 # print(image.shape)
#       8 # image = torch.unsqueeze(image, dim=0)
#       9 # print(caption.shape)
#      10 # image = image.to(device = torch.device('cuda')),.,
#      11 # caption = caption.to(device = torch.device('cuda'))
#      12 optimizer.zero_grad()
# ---> 13 output =  model(image, caption[0])
#      14 # print(output, grad_info)
#      15 # break
#      16 loss_list.append(output.item())
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[49], line 25, in CustomResNet.forward(self, image, caption_list)
#      24 def forward(self, image, caption_list):
# ---> 25     out_backbone = self.backbone(image)
#      27     hidden = out_backbone.squeeze(0)
#      28     # print(f"the hidden shape from image is {hidden.shape}")
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torch\nn\modules\container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torchvision\models\resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torchvision\models\resnet.py:276, in ResNet._forward_impl(self, x)
#     274 x = self.layer2(x)
#     275 x = self.layer3(x)
# --> 276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#     279 x = torch.flatten(x, 1)
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torch\nn\modules\container.py:204, in Sequential.forward(self, input)
#     202 def forward(self, input):
#     203     for module in self:
# --> 204         input = module(input)
#     205     return input
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torchvision\models\resnet.py:146, in Bottleneck.forward(self, x)
#     143 def forward(self, x: Tensor) -> Tensor:
#     144     identity = x
# --> 146     out = self.conv1(x)
#     147     out = self.bn1(out)
#     148     out = self.relu(out)
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torch\nn\modules\conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\Anant\anaconda3\lib\site-packages\torch\nn\modules\conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
p = torch.tensor([[1,2,3,4]])
x = torch.argmax(p, dim = 1)
x
# Out:
# tensor([3])

# %%
p = torch.tensor([1.0,2.0,2.0,4.0], requires_grad=True)
q = torch.tensor([3.0,4.0,5.0,6.0], requires_grad=True)
s  = torch.sum(p+q, dim = 0)
print(s)
s.backward()
# Out:
# tensor(27., grad_fn=<SumBackward1>)

# %%
loss = nn.CrossEntropyLoss()
input = torch.randn(3, 5, requires_grad=True)
target = torch.empty(3, dtype=torch.long).random_(5)
output = loss(input, target)

# %%
print(input)
# Out:
# tensor([[-0.7649, -0.7517, -0.6849, -0.0564, -1.0063],
#         [-0.8070,  0.1536, -0.1430,  0.6772,  0.7898],
#         [ 0.4916, -0.5202, -0.5325,  0.3402, -0.7753]], requires_grad=True)

# %%
print(target)
# Out:
# tensor([0, 2, 3])

# %%
print(output)
# Out:
# tensor(1.6728, grad_fn=<NllLossBackward0>)

# %%
import pandas as pd
image_captions_df = pd.read_parquet('F://coco/captions/image_captions_df_new.parquet')
image_captions_df
# Out:
#        image_id                        file_name  \
# 0         57870  COCO_train2014_000000057870.jpg
# 1        384029  COCO_train2014_000000384029.jpg
# 2        222016  COCO_train2014_000000222016.jpg
# 3        520950  COCO_train2014_000000520950.jpg
# 4         69675  COCO_train2014_000000069675.jpg
# ...         ...                              ...
# 66658    360271  COCO_train2014_000000360271.jpg
# 66659    471345  COCO_train2014_000000471345.jpg
# 66660    444010  COCO_train2014_000000444010.jpg
# 66661    565004  COCO_train2014_000000565004.jpg
# 66662    516168  COCO_train2014_000000516168.jpg
#
#                                                 captions  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66659  [[a, table, topped, with, two, white, plates, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                        caption_token_set  \
# 0      [arrangement, is, flower, on, table, blue, top...
# 1      [types, desserts, person, is, kitchen, many, u...
# 2      [inside, person, image, standing, is, an, that...
# 3      [is, on, that, kitchen, all, utilizes, with, i...
# 4      [child, woman, person, on, women, an, together...
# ...                                                  ...
# 66658  [woman, another, dinner., sitting, is, watchin...
# 66659  [lobster,, rice., sitting, is, on, table, sit,...
# 66660  [woman, jovial, sitting, table, group, togethe...
# 66661  [another, is, on, table, wine, with, red, glas...
# 66662  [paper, glases, standing, is, sitting, on, tab...
#
#                                             idx_captions  \
# 0      [[27, 13, 25, 23, 9, 30, 12, 19], [27, 22, 13,...
# 1      [[27, 53, 56, 33, 29, 27, 35, 42, 29, 50], [27...
# 2      [[27, 66, 62, 67, 65, 61, 27, 53, 1, 59, 29], ...
# 3      [[20, 35, 1, 73, 28, 80, 3, 20, 75], [27, 35, ...
# 4      [[27, 88, 12, 89, 94, 98, 29, 20, 99], [27, 89...
# ...                                                  ...
# 66658  [[90, 215, 102, 27, 311, 4, 7, 140, 145, 102, ...
# 66659  [[27, 4, 283, 7, 103, 118, 427, 28, 97, 163, 1...
# 66660  [[27, 362, 28, 2829, 215, 144, 102, 27, 4, 330...
# 66661  [[418, 319, 6776, 161, 27, 686, 139, 27, 4], [...
# 66662  [[27, 53, 1, 59, 135, 27, 3694, 7, 15795], [27...
#
#                                                   tokens
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66659  [[a, table, topped, with, two, white, plates, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
# [66663 rows x 6 columns]

# %%
image_captions_df['tokens'][0]
# Out:
# array([array(['a', 'restaurant', 'has', 'modern', 'wooden', 'tables', 'and',
#               'chairs', '.'], dtype=object)                                 ,
#        array(['a', 'long', 'restaurant', 'table', 'with', 'rattan', 'rounded',
#               'back', 'chairs', '.'], dtype=object)                           ,
#        array(['a', 'long', 'table', 'with', 'a', 'plant', 'on', 'top', 'of',
#               'it', 'surrounded', 'with', 'wooden', 'chairs'], dtype=object),
#        array(['a', 'long', 'table', 'with', 'a', 'flower', 'arrangement', 'in',
#               'the', 'middle', 'for', 'meetings'], dtype=object)               ,
#        array(['a', 'table', 'is', 'adorned', 'with', 'wooden', 'chairs', 'with',
#               'blue', 'accents', '.'], dtype=object)                            ],
#       dtype=object)

# %%
def find_shortest_tokens(token_list):
    min_len = 1000
    shortest_token = None
    for token in token_list:
        if len(token) <min_len:
            shortest_token = token
    return shortest_token

image_captions_df['shortest_token'] = image_captions_df['tokens'].apply(lambda x : find_shortest_tokens(x))
image_captions_df['shortest_token_len'] = image_captions_df['shortest_token'].apply(lambda x : len(x))
image_captions_df
# Out:
#        image_id                        file_name  \
# 0         57870  COCO_train2014_000000057870.jpg
# 1        384029  COCO_train2014_000000384029.jpg
# 2        222016  COCO_train2014_000000222016.jpg
# 3        520950  COCO_train2014_000000520950.jpg
# 4         69675  COCO_train2014_000000069675.jpg
# ...         ...                              ...
# 66658    360271  COCO_train2014_000000360271.jpg
# 66659    471345  COCO_train2014_000000471345.jpg
# 66660    444010  COCO_train2014_000000444010.jpg
# 66661    565004  COCO_train2014_000000565004.jpg
# 66662    516168  COCO_train2014_000000516168.jpg
#
#                                                 captions  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66659  [[a, table, topped, with, two, white, plates, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                        caption_token_set  \
# 0      [arrangement, is, flower, on, table, blue, top...
# 1      [types, desserts, person, is, kitchen, many, u...
# 2      [inside, person, image, standing, is, an, that...
# 3      [is, on, that, kitchen, all, utilizes, with, i...
# 4      [child, woman, person, on, women, an, together...
# ...                                                  ...
# 66658  [woman, another, dinner., sitting, is, watchin...
# 66659  [lobster,, rice., sitting, is, on, table, sit,...
# 66660  [woman, jovial, sitting, table, group, togethe...
# 66661  [another, is, on, table, wine, with, red, glas...
# 66662  [paper, glases, standing, is, sitting, on, tab...
#
#                                             idx_captions  \
# 0      [[27, 13, 25, 23, 9, 30, 12, 19], [27, 22, 13,...
# 1      [[27, 53, 56, 33, 29, 27, 35, 42, 29, 50], [27...
# 2      [[27, 66, 62, 67, 65, 61, 27, 53, 1, 59, 29], ...
# 3      [[20, 35, 1, 73, 28, 80, 3, 20, 75], [27, 35, ...
# 4      [[27, 88, 12, 89, 94, 98, 29, 20, 99], [27, 89...
# ...                                                  ...
# 66658  [[90, 215, 102, 27, 311, 4, 7, 140, 145, 102, ...
# 66659  [[27, 4, 283, 7, 103, 118, 427, 28, 97, 163, 1...
# 66660  [[27, 362, 28, 2829, 215, 144, 102, 27, 4, 330...
# 66661  [[418, 319, 6776, 161, 27, 686, 139, 27, 4], [...
# 66662  [[27, 53, 1, 59, 135, 27, 3694, 7, 15795], [27...
#
#                                                   tokens  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66659  [[a, table, topped, with, two, white, plates, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                           shortest_token  shortest_token_len
# 0      [a, table, is, adorned, with, wooden, chairs, ...                  11
# 1      [close, up, of, a, hand, touching, various, pa...                   9
# 2      [a, man, using, a, phone, in, a, phone, booth, .]                  10
# 3      [a, very, small, kitchen, with, a, stove, and,...                  12
# 4      [two, women, cooking, on, stove, in, a, kitche...                  10
# ...                                                  ...                 ...
# 66658   [a, bunch, of, women, are, eating, at, a, table]                   9
# 66659  [there, is, lobster, ,, rice, ,, and, a, salad...                  16
# 66660  [a, jovial, older, couple, and, a, young, woma...                  14
# 66661  [a, wine, glass, being, filled, with, red, win...                   9
# 66662  [a, man, is, sitting, at, a, table, with, pape...                  13
#
# [66663 rows x 8 columns]

# %%
less_than_15_image_caption_df = image_captions_df[image_captions_df['shortest_token_len'] <= 15]

# %% [markdown]
# # This is a new

# %%
import pandas as pd
image_captions_df = pd.read_parquet('F://coco/captions/image_captions_df_less_than_15.parquet')
image_captions_df
# Out:
#        image_id                        file_name  \
# 0         57870  COCO_train2014_000000057870.jpg
# 1        384029  COCO_train2014_000000384029.jpg
# 2        222016  COCO_train2014_000000222016.jpg
# 3        520950  COCO_train2014_000000520950.jpg
# 4         69675  COCO_train2014_000000069675.jpg
# ...         ...                              ...
# 66657     53136  COCO_train2014_000000053136.jpg
# 66658    360271  COCO_train2014_000000360271.jpg
# 66660    444010  COCO_train2014_000000444010.jpg
# 66661    565004  COCO_train2014_000000565004.jpg
# 66662    516168  COCO_train2014_000000516168.jpg
#
#                                                 captions  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66657  [[vegetable, and, rice, dish, served, in, a, w...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                        caption_token_set  \
# 0      [arrangement, is, flower, on, table, blue, top...
# 1      [types, desserts, person, is, kitchen, many, u...
# 2      [inside, person, image, standing, is, an, that...
# 3      [is, on, that, kitchen, all, utilizes, with, i...
# 4      [child, woman, person, on, women, an, together...
# ...                                                  ...
# 66657  [bed, vegetables, on, white, top, with, pasta,...
# 66658  [woman, another, dinner., sitting, is, watchin...
# 66660  [woman, jovial, sitting, table, group, togethe...
# 66661  [another, is, on, table, wine, with, red, glas...
# 66662  [paper, glases, standing, is, sitting, on, tab...
#
#                                             idx_captions  \
# 0      [[27, 13, 25, 23, 9, 30, 12, 19], [27, 22, 13,...
# 1      [[27, 53, 56, 33, 29, 27, 35, 42, 29, 50], [27...
# 2      [[27, 66, 62, 67, 65, 61, 27, 53, 1, 59, 29], ...
# 3      [[20, 35, 1, 73, 28, 80, 3, 20, 75], [27, 35, ...
# 4      [[27, 88, 12, 89, 94, 98, 29, 20, 99], [27, 89...
# ...                                                  ...
# 66657  [[2753, 12, 2778, 339, 995, 29, 27, 118, 358],...
# 66658  [[90, 215, 102, 27, 311, 4, 7, 140, 145, 102, ...
# 66660  [[27, 362, 28, 2829, 215, 144, 102, 27, 4, 330...
# 66661  [[418, 319, 6776, 161, 27, 686, 139, 27, 4], [...
# 66662  [[27, 53, 1, 59, 135, 27, 3694, 7, 15795], [27...
#
#                                                   tokens  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66657  [[vegetable, and, rice, dish, served, in, a, w...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                           shortest_token  shortest_token_len
# 0      [a, table, is, adorned, with, wooden, chairs, ...                  11
# 1      [close, up, of, a, hand, touching, various, pa...                   9
# 2      [a, man, using, a, phone, in, a, phone, booth, .]                  10
# 3      [a, very, small, kitchen, with, a, stove, and,...                  12
# 4      [two, women, cooking, on, stove, in, a, kitche...                  10
# ...                                                  ...                 ...
# 66657  [a, white, bowl, contains, shredded, cabbage, ...                   9
# 66658   [a, bunch, of, women, are, eating, at, a, table]                   9
# 66660  [a, jovial, older, couple, and, a, young, woma...                  14
# 66661  [a, wine, glass, being, filled, with, red, win...                   9
# 66662  [a, man, is, sitting, at, a, table, with, pape...                  13
#
# [62726 rows x 8 columns]

# %% [markdown]
# Now first what we need to do is to create a vocabulary and convert the tokens to integers so that we can get the embeddings.

# %%
def make_vocab(token_list):
    """ This function takes in a token list and adds the unique tokens to the vocabulary."""
    for tokens in  token_list:
        for token in tokens:
            if token in vocab_dict:
                vocab_dict[token] +=1
            else:
                vocab_dict[token] = 1
    return vocab_dict


def stoi(captions_list, chartoidx):
    """ Function to convert the string tokens to integers.
        Also adds the <start>, <end> & <unk> tokens to form the final list to be fed in the RNN
        INPUT --> list of captions with 
        OUPUT --> """
    caption_token_list = []
    for caption in captions_list:
        tokens_list = [chartoidx['<start>']] + []
        for token in caption:
            try:
                tokens_list.append(chartoidx[token])
            except:
                tokens_list.append(chartoidx['<unk>'])
        tokens_list = tokens_list + [chartoidx['<end>']]
        caption_token_list.append(tokens_list)
    return caption_token_list

# %%
vocab_dict = {}
image_captions_df['tokens'].apply(lambda x : make_vocab(x))

chartoidx = {}    # create the character to index dictionary for tokens and their integer representations.
idxtochar = []    # index to char list. Useful for decoding the output from the neural net. 
for i,word in enumerate(vocab_dict.keys()):
    chartoidx[word] = i
    idxtochar.append(word)

idxtochar = idxtochar + ['<unk>','<start>','<end>','<pad>']    # add additional tokens
chartoidx.update({'<unk>':21573,                       # add addtional tokens and their corresponding numbers 
                        '<start>':21574,
                        '<end>':21575,
                        '<pad>':21576})

# Add an idx_tokens column to the dataframe to house the integer representation of the token strings.
image_captions_df['idx_tokens'] = image_captions_df['tokens'].apply(lambda x : stoi(x, chartoidx))
image_captions_df
# Out:
#        image_id                        file_name  \
# 0         57870  COCO_train2014_000000057870.jpg
# 1        384029  COCO_train2014_000000384029.jpg
# 2        222016  COCO_train2014_000000222016.jpg
# 3        520950  COCO_train2014_000000520950.jpg
# 4         69675  COCO_train2014_000000069675.jpg
# ...         ...                              ...
# 66657     53136  COCO_train2014_000000053136.jpg
# 66658    360271  COCO_train2014_000000360271.jpg
# 66660    444010  COCO_train2014_000000444010.jpg
# 66661    565004  COCO_train2014_000000565004.jpg
# 66662    516168  COCO_train2014_000000516168.jpg
#
#                                                 captions  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66657  [[vegetable, and, rice, dish, served, in, a, w...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                        caption_token_set  \
# 0      [arrangement, is, flower, on, table, blue, top...
# 1      [types, desserts, person, is, kitchen, many, u...
# 2      [inside, person, image, standing, is, an, that...
# 3      [is, on, that, kitchen, all, utilizes, with, i...
# 4      [child, woman, person, on, women, an, together...
# ...                                                  ...
# 66657  [bed, vegetables, on, white, top, with, pasta,...
# 66658  [woman, another, dinner., sitting, is, watchin...
# 66660  [woman, jovial, sitting, table, group, togethe...
# 66661  [another, is, on, table, wine, with, red, glas...
# 66662  [paper, glases, standing, is, sitting, on, tab...
#
#                                             idx_captions  \
# 0      [[27, 13, 25, 23, 9, 30, 12, 19], [27, 22, 13,...
# 1      [[27, 53, 56, 33, 29, 27, 35, 42, 29, 50], [27...
# 2      [[27, 66, 62, 67, 65, 61, 27, 53, 1, 59, 29], ...
# 3      [[20, 35, 1, 73, 28, 80, 3, 20, 75], [27, 35, ...
# 4      [[27, 88, 12, 89, 94, 98, 29, 20, 99], [27, 89...
# ...                                                  ...
# 66657  [[2753, 12, 2778, 339, 995, 29, 27, 118, 358],...
# 66658  [[90, 215, 102, 27, 311, 4, 7, 140, 145, 102, ...
# 66660  [[27, 362, 28, 2829, 215, 144, 102, 27, 4, 330...
# 66661  [[418, 319, 6776, 161, 27, 686, 139, 27, 4], [...
# 66662  [[27, 53, 1, 59, 135, 27, 3694, 7, 15795], [27...
#
#                                                   tokens  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66657  [[vegetable, and, rice, dish, served, in, a, w...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                           shortest_token  shortest_token_len  \
# 0      [a, table, is, adorned, with, wooden, chairs, ...                  11
# 1      [close, up, of, a, hand, touching, various, pa...                   9
# 2      [a, man, using, a, phone, in, a, phone, booth, .]                  10
# 3      [a, very, small, kitchen, with, a, stove, and,...                  12
# 4      [two, women, cooking, on, stove, in, a, kitche...                  10
# ...                                                  ...                 ...
# 66657  [a, white, bowl, contains, shredded, cabbage, ...                   9
# 66658   [a, bunch, of, women, are, eating, at, a, table]                   9
# 66660  [a, jovial, older, couple, and, a, young, woma...                  14
# 66661  [a, wine, glass, being, filled, with, red, win...                   9
# 66662  [a, man, is, sitting, at, a, table, with, pape...                  13
#
#                                               idx_tokens
# 0      [[21574, 0, 1, 2, 3, 4, 5, 6, 7, 8, 21575], [2...
# 1      [[21574, 0, 32, 33, 34, 23, 0, 35, 36, 23, 37,...
# 2      [[21574, 0, 57, 58, 59, 60, 61, 0, 32, 28, 62,...
# 3      [[21574, 24, 35, 28, 69, 18, 70, 16, 24, 71, 2...
# 4      [[21574, 0, 87, 6, 88, 89, 90, 23, 24, 35, 8, ...
# ...                                                  ...
# 66657  [[21574, 2147, 6, 2167, 297, 813, 23, 0, 118, ...
# 66658  [[21574, 100, 198, 92, 0, 278, 10, 11, 125, 12...
# 66660  [[21574, 0, 330, 18, 2209, 198, 133, 92, 0, 10...
# 66661  [[21574, 343, 285, 4815, 144, 0, 550, 131, 0, ...
# 66662  [[21574, 0, 32, 28, 62, 141, 0, 264, 11, 10659...
#
# [62726 rows x 9 columns]

# %%
def convert_shortest_token(token_list,chartoidx):
    new_token_list = [chartoidx['<start>']]
    for token in token_list:
        new_token_list = new_token_list  + [chartoidx[token]]
    new_token_list = new_token_list + [chartoidx['<end>']]
    return new_token_list

# %%
image_captions_df['shortest_idx_tokens'] = image_captions_df['shortest_token'].apply(lambda x : convert_shortest_token(x, chartoidx))
image_captions_df
# Out:
#        image_id                        file_name  \
# 0         57870  COCO_train2014_000000057870.jpg
# 1        384029  COCO_train2014_000000384029.jpg
# 2        222016  COCO_train2014_000000222016.jpg
# 3        520950  COCO_train2014_000000520950.jpg
# 4         69675  COCO_train2014_000000069675.jpg
# ...         ...                              ...
# 66657     53136  COCO_train2014_000000053136.jpg
# 66658    360271  COCO_train2014_000000360271.jpg
# 66660    444010  COCO_train2014_000000444010.jpg
# 66661    565004  COCO_train2014_000000565004.jpg
# 66662    516168  COCO_train2014_000000516168.jpg
#
#                                                 captions  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66657  [[vegetable, and, rice, dish, served, in, a, w...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                        caption_token_set  \
# 0      [arrangement, is, flower, on, table, blue, top...
# 1      [types, desserts, person, is, kitchen, many, u...
# 2      [inside, person, image, standing, is, an, that...
# 3      [is, on, that, kitchen, all, utilizes, with, i...
# 4      [child, woman, person, on, women, an, together...
# ...                                                  ...
# 66657  [bed, vegetables, on, white, top, with, pasta,...
# 66658  [woman, another, dinner., sitting, is, watchin...
# 66660  [woman, jovial, sitting, table, group, togethe...
# 66661  [another, is, on, table, wine, with, red, glas...
# 66662  [paper, glases, standing, is, sitting, on, tab...
#
#                                             idx_captions  \
# 0      [[27, 13, 25, 23, 9, 30, 12, 19], [27, 22, 13,...
# 1      [[27, 53, 56, 33, 29, 27, 35, 42, 29, 50], [27...
# 2      [[27, 66, 62, 67, 65, 61, 27, 53, 1, 59, 29], ...
# 3      [[20, 35, 1, 73, 28, 80, 3, 20, 75], [27, 35, ...
# 4      [[27, 88, 12, 89, 94, 98, 29, 20, 99], [27, 89...
# ...                                                  ...
# 66657  [[2753, 12, 2778, 339, 995, 29, 27, 118, 358],...
# 66658  [[90, 215, 102, 27, 311, 4, 7, 140, 145, 102, ...
# 66660  [[27, 362, 28, 2829, 215, 144, 102, 27, 4, 330...
# 66661  [[418, 319, 6776, 161, 27, 686, 139, 27, 4], [...
# 66662  [[27, 53, 1, 59, 135, 27, 3694, 7, 15795], [27...
#
#                                                   tokens  \
# 0      [[a, restaurant, has, modern, wooden, tables, ...
# 1      [[a, man, preparing, desserts, in, a, kitchen,...
# 2      [[a, big, red, telephone, booth, that, a, man,...
# 3      [[the, kitchen, is, full, of, spices, on, the,...
# 4      [[a, child, and, woman, are, cooking, in, the,...
# ...                                                  ...
# 66657  [[vegetable, and, rice, dish, served, in, a, w...
# 66658  [[women, sitting, at, a, dinner, table, with, ...
# 66660  [[a, group, of, friends, sitting, down, at, a,...
# 66661  [[wine, being, poured, into, a, glass, over, a...
# 66662  [[a, man, is, standing, behind, a, bar, with, ...
#
#                                           shortest_token  shortest_token_len  \
# 0      [a, table, is, adorned, with, wooden, chairs, ...                  11
# 1      [close, up, of, a, hand, touching, various, pa...                   9
# 2      [a, man, using, a, phone, in, a, phone, booth, .]                  10
# 3      [a, very, small, kitchen, with, a, stove, and,...                  12
# 4      [two, women, cooking, on, stove, in, a, kitche...                  10
# ...                                                  ...                 ...
# 66657  [a, white, bowl, contains, shredded, cabbage, ...                   9
# 66658   [a, bunch, of, women, are, eating, at, a, table]                   9
# 66660  [a, jovial, older, couple, and, a, young, woma...                  14
# 66661  [a, wine, glass, being, filled, with, red, win...                   9
# 66662  [a, man, is, sitting, at, a, table, with, pape...                  13
#
#                                               idx_tokens  \
# 0      [[21574, 0, 1, 2, 3, 4, 5, 6, 7, 8, 21575], [2...
# 1      [[21574, 0, 32, 33, 34, 23, 0, 35, 36, 23, 37,...
# 2      [[21574, 0, 57, 58, 59, 60, 61, 0, 32, 28, 62,...
# 3      [[21574, 24, 35, 28, 69, 18, 70, 16, 24, 71, 2...
# 4      [[21574, 0, 87, 6, 88, 89, 90, 23, 24, 35, 8, ...
# ...                                                  ...
# 66657  [[21574, 2147, 6, 2167, 297, 813, 23, 0, 118, ...
# 66658  [[21574, 100, 198, 92, 0, 278, 10, 11, 125, 12...
# 66660  [[21574, 0, 330, 18, 2209, 198, 133, 92, 0, 10...
# 66661  [[21574, 343, 285, 4815, 144, 0, 550, 131, 0, ...
# 66662  [[21574, 0, 32, 28, 62, 141, 0, 264, 11, 10659...
#
#                                      shortest_idx_tokens
# 0      [21574, 0, 10, 28, 29, 11, 4, 7, 11, 30, 31, 8...
# 1       [21574, 49, 50, 18, 0, 55, 56, 45, 42, 8, 21575]
# 2      [21574, 0, 32, 68, 0, 64, 23, 0, 64, 60, 8, 21...
# 3      [21574, 0, 84, 41, 35, 11, 0, 85, 6, 0, 86, 18...
# 4      [21574, 99, 100, 90, 16, 85, 23, 0, 35, 101, 8...
# ...                                                  ...
# 66657  [21574, 0, 118, 472, 2315, 2299, 2146, 6, 2607...
# 66658  [21574, 0, 276, 18, 100, 89, 617, 92, 0, 10, 2...
# 66660  [21574, 0, 5737, 98, 275, 6, 0, 93, 88, 1902, ...
# 66661  [21574, 0, 343, 550, 285, 171, 11, 58, 343, 8,...
# 66662  [21574, 0, 32, 28, 198, 92, 0, 10, 11, 1544, 6...
#
# [62726 rows x 10 columns]

# %% [markdown]
# First and foremost we would have to change the way that we are making the dataset because previously we were giving all the five caption and then taking the first from them. Now we would have to give only one caption.

# %%
class CocoDataset(Dataset):
    def __init__(self,image_label_df, val_stride = 10, is_val_set_bool = False, test_data_set =False, test_stride = 5, transforms = None):
        
        self.transfrom = transforms
        self.is_val_set_bool = is_val_set_bool
        self.val_stride = val_stride
        self.image_label_df = image_label_df.copy()
        self.test_data_set = test_data_set
        self.test_stride = test_stride

        if self.test_data_set: #If we need only a small subset of the data to work with
            self.image_label_df = self.image_label_df[::test_stride].reset_index(drop = True)

        elif self.is_val_set_bool: # If we need only the validation data then return the validation data which is a subset of total data
            assert self.val_stride > 0
            self.image_label_df = self.image_label_df[::val_stride]

        elif self.val_stride > 0:  # Else if val_stride is greater than zero then return the remaining dataframe after removing 10% of data
            self.image_label_df = self.image_label_df.drop(index = list(range(0,len(self.image_label_df),self.val_stride)))
            
        else: # else train on the full dataset
            self.image_label_df = self.image_label_df
        
    def __len__(self):
        """ This method calculates the length of your data."""
        return len(self.image_label_df)

    # Now we will introduce function which gives us an image and its corresponding labels by id
    def get_image_by_id(self, img_id = None):
        """ This function returns an image by its id and the corresponding multiple labesl in a present/no_present binary format"""
        

        folder_path = 'F://coco/train2014/train2014/'

        if img_id == None:
            raise ValueError('Must provide IMAGE ID')

        else:
            row = self.image_label_df[self.image_label_df['image_id']==img_id]
            file_name = row['file_name'].values[0]

            captions_array = torch.tensor(row['idx_tokens'][0][0])

            # Get the image-data from file_name
            image_array = torchvision.io.read_image(folder_path + file_name)
            image_array = (image_array/255.0).to(torch.float32)
            image_array = self.transfrom(image_array).to(torch.float32)
        
            return image_array, captions_array


    # Now we would write the code for returning the image from index and its corresponding labels. Which would be used by the train/val dataloaders
    def __getitem__(self, ndx):

        """ This function takes in an index and returns the image and the labels of the image at that index"""
        folder_path = 'F://coco/train2014/train2014/'
        
        row = self.image_label_df.iloc[ndx]
        # print(row)

        # Now get the image_id and the file_name of the image
        image_id = row['image_id']
        file_name = row['file_name']
        
        # Now get the captions array from the dataframe
        captions_array = torch.tensor(row['idx_tokens'][0])
        # Now get the image_data from storage
        image_array = torchvision.io.read_image(folder_path + file_name)
        image_array = (image_array/255.0).to(torch.float32)
        image_array = self.transfrom(image_array).to(torch.float32)
        # print(captions_array)
        return (image_array, captions_array, image_id)
